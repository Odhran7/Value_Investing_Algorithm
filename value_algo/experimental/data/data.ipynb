# %%
# This file handles the classes for the valuation of a stock using traditional methods

import yfinance as yf
import pandas as pd
import numpy as np


# Valuation object to handle the traditional dcf valuation methods
class Valuation:
    def __init__(self, stock):
        self.stock = stock

    def get_value(self):
        raise NotImplementedError("Subclasses should implement this method")

    def test(self):
        raise NotImplementedError("Subclasses should implement this method")
    
    def get_valuation_ratios(self):
        raise NotImplementedError("Subclasses should implement this method")

"""
Valuation object to handle the traditional dcf valuation methods
Requires:
- stock object as yf.Ticker
- ten year treasury yield ideal holding point
- current inflation rate
- last years s and p 500 returns 
- dividend payout ratio for the company
"""
class DCFValuation(Valuation):
    def __init__(self, stock, inflation_rate, periods=4):
        super().__init__(stock)
        self.inflation_rate = inflation_rate
        self.periods = periods
        self.last_sp500_return = self.__get_market_rate_of_return()
        self.risk_free_rate = self.__get_risk_free_rate()

    def __get_treasury_yields(self):
        treasury_ticker = '^TNX'
        treasury_data = yf.Ticker(treasury_ticker)
        treasury_yield = treasury_data.history(period='5d')['Close'].iloc[-1]
        risk_free_rate = treasury_yield / 100
        
        return risk_free_rate

    def __get_market_rate_of_return(self):
        sp500 = yf.Ticker('^GSPC')
        sp500_data = sp500.history(period='10y')
        sp500_data['Yearly Return'] = sp500_data['Close'].pct_change(periods=252)
        yearly_returns = sp500_data['Yearly Return'].dropna()
        avg_annual_return = yearly_returns.mean()
        
        return avg_annual_return

    def __get_risk_free_rate(self):
        raw_risk_free_rate = self.__get_treasury_yields()
        nominal_risk_free_rate = (1 + raw_risk_free_rate) * (1 + self.inflation_rate) - 1

        return nominal_risk_free_rate

    def __get_cash_flows(self):
        try:
            cash_flows = self.stock.cash_flow.loc['Free Cash Flow'].iloc[:self.periods].to_numpy()
        except KeyError:
            cash_flows = self.stock.cash_flow.loc['Operating Cash Flow'].iloc[:self.periods].to_numpy()
        return list(cash_flows)
    
    def __get_growth_rate(self):
        cash_flows = self.__get_cash_flows()
        growth_rates = []
        for i in range(1, len(cash_flows)):
            yearOne, yearTwo = cash_flows[i - 1], cash_flows[i]
            curr_growth_rate = (yearTwo - yearOne) / yearOne
            growth_rates.append(curr_growth_rate)
        return (sum(growth_rates) / len(growth_rates))

    def cost_of_equity(self):
        # risk free rate + beta * (market rate of return - risk-free-rate of return)
        beta = self.stock.df.get('beta', 1)
        nominal_risk_free_rate = self.risk_free_rate
        market_rate_of_return = self.last_sp500_return
        cost_of_equity = (nominal_risk_free_rate + beta * (market_rate_of_return - nominal_risk_free_rate))

        return cost_of_equity

    def cost_of_debt(self):
        credit_spread = self.__get_credit_spread()
        tax_rate = self.__get_tax_rate()
        nominal_risk_free_rate = self.risk_free_rate    
        current_credit_spread = credit_spread[0]
        # (After tax cost of debt + Credit Spread) * (1 - tax rate)
        cost_of_debt = (nominal_risk_free_rate + current_credit_spread) * (1 - tax_rate)

        return cost_of_debt
    
    def get_wacc(self):
    
        tax_rate = self.__get_tax_rate()
        cost_of_equity = self.cost_of_equity()
        cost_of_debt = self.cost_of_debt()
        equity_weight, debt_weight = self.get_weights()
        # WACC = (equity weight * cost of equity) + debt weight * cosst of detb * (1 - tax rate)
        wacc = (equity_weight * cost_of_equity) + (debt_weight * cost_of_debt * (1 - tax_rate))

        return wacc

    def get_weights(self):
        def get_market_value_of_equity():
            market_cap = self.stock.df.get('marketCap')
            return market_cap
        
        def get_market_cap_of_debt():
            total_debt = self.stock.balance_sheet.loc['Total Debt'].iloc[0]
            return total_debt

        equity = get_market_value_of_equity()
        total_debt = get_market_cap_of_debt()

        equity_weight = equity / (equity + total_debt)
        debt_weight = total_debt / (equity + total_debt)

        return equity_weight, debt_weight
    
    def __get_tax_rate(self):
        return self.stock.income_stmt.loc['Tax Rate For Calcs'].iloc[0]
    
    def __get_credit_spread(self):
            real_risk_free_rate = self.risk_free_rate
            interest_expense = self.stock.obtain_interest_expense(periods=self.periods)
            total_debt = self.stock.balance_sheet.loc['Total Debt'].iloc[:self.periods].to_numpy()
            average_interest_expense = [self.risk_free_rate if interest_expense[i] == 0 else interest_expense[i] / total_debt[i] for i in range(len(total_debt))]
            credit_spread = list(map(lambda avg_interest: avg_interest - real_risk_free_rate, average_interest_expense))

            return credit_spread
    

    def __calcuate_terminal_value(self, growth_rate, wacc):
        # Infinite growth rate == 0.02
        final_year_fcf = self.stock.cash_flow.loc['Free Cash Flow'].iloc[0]
        if growth_rate < 0:
            perpetuity_growth_rate = 0
        else:
            perpetuity_growth_rate = 0.02
        # (final year fcf * (1 + perpetuity growth rate)) / (discount rate or wacc - perpetuiyt growth rate)
        terminal_value = (final_year_fcf * (1 + perpetuity_growth_rate)) / (wacc - perpetuity_growth_rate)

        return terminal_value

    def get_valuation_ratios(self):
        dcf_valuation_ratio = self.__get_dcf_value() / self.stock.df.get('marketCap')
        free_cash_flow = self.stock.cash_flow.loc['Free Cash Flow'].iloc[:self.periods].to_numpy()
        if len(free_cash_flow) < self.periods:
            free_cash_flow = np.append(free_cash_flow, free_cash_flow[-1] * self.periods - len(free_cash_flow))
        cash_flow1, cash_flow2, cash_flow3, cash_flow4 = free_cash_flow[0], free_cash_flow[1], free_cash_flow[2], free_cash_flow[3]
        growth_rate = self.__get_growth_rate()
        wacc = self.get_wacc()
        cost_of_equity = self.cost_of_equity()
        cost_of_debt = self.cost_of_debt()

        return [dcf_valuation_ratio, cash_flow1, cash_flow2, cash_flow3, cash_flow4, growth_rate, wacc, cost_of_equity, cost_of_debt]

    def __get_dcf_value(self):
        growth_rate = self.__get_growth_rate()
        wacc = self.get_wacc()
        cash_flows = self.__get_cash_flows()
        forecasted_fcfs = []

        # 1. Forecast the cash flows

        for i in range(self.periods):
            fcf = cash_flows[-1] * ((1 + growth_rate) ** (i + 1))
            forecasted_fcfs.append(fcf)

        # 2. Discount the cash flows

        discounted_fcfs = [fcf / ((1 + wacc) ** (i + 1)) for i, fcf in enumerate(forecasted_fcfs)]

        # 3. Calculate the terminal value

        terminal_value = self.__calcuate_terminal_value(growth_rate, wacc)

        # 4. Discount the terminal value

        discounted_terminal_value = terminal_value / ((1 + wacc) ** self.periods)

        # 5. Sum the present values

        dcf_value = sum(discounted_fcfs) + discounted_terminal_value

        return dcf_value

    def get_value(self):
        return self.__get_dcf_value()

    def test(self):
        try:
            market_cap = self.stock.df.get('marketCap')
            wacc = self.get_wacc()
            growth_rate = self.__get_growth_rate()
            terminal_value = self.__calcuate_terminal_value(growth_rate, wacc)
            dcf_value = self.__get_dcf_value()
            
            print(f"Ticker: {self.stock.ticker}")
            print(f"Risk Free Rate: {self.risk_free_rate}")
            print(f"Market Cap: {market_cap}")
            print(f"WACC: {wacc}")
            print(f"Growth Rate: {growth_rate}")
            print(f"Terminal Value: {terminal_value}")
            print(f"DCF Value: {dcf_value}")
            print(f"Valuation ratio: {dcf_value / market_cap:.2f}")
        except Exception as e:
            print(f"Failed to obtain data for {self.ticker}.")
            print(e)

"""
Object to handle the dividend discount model
We will assume a gordon growth model for the data and calculate the intrinsic value of the stock
"""
class DDMValuation(Valuation):
    def __init__(self, stock):
        super().__init__(stock)
        self.dividend_payout_ratio = self.__calculate_dividend_payout_ratio()

    def __calculate_dividend_payout_ratio(self):
        div_yield = self.stock.df.get('dividendYield', 0) * 100
        pe_ratio = self.stock.df.get('trailingPE', 0)
        dividend_payout_ratio = div_yield / (pe_ratio + 1e-10)
        if pd.isna(dividend_payout_ratio):
            dividend_payout_ratio = 0
        return dividend_payout_ratio
    
    def check(self):
        return self.dividend_payout_ratio > 0.15

    def __get_current_stock_price(self):
        return self.stock.df.get('previousClose')
    
    def __calculate_historical_growth(self, periods=0):
        if periods:
            pct_changes = self.stock.dividends.pct_change(periods=periods)
        else:
            pct_changes = self.stock.dividends.pct_change()
        lower, upper = pct_changes.quantile(0.025), pct_changes.quantile(0.975)
        filtered_pct_changes = pct_changes[(pct_changes >= lower) & (pct_changes <= upper)]
        return filtered_pct_changes.mean()

    def __calculate_rolling_average_growth(self, window=10):
        rolling_growth = self.stock.dividends.pct_change().rolling(window=window).mean()
        return rolling_growth.mean()

    def __calculate_combined_growth(self, short_period=5, long_period=10):
        short_term_growth = self.__calculate_historical_growth(periods=short_period)
        long_term_growth = self.__calculate_historical_growth(periods=long_period)
        combined_growth = (0.4 * short_term_growth) + (0.6 * long_term_growth)
        return combined_growth

    def __get_realistic_growth_rate(self):
        historical_growth = self.__calculate_historical_growth()
        rolling_average_growth = self.__calculate_rolling_average_growth()
        combined_growth = self.__calculate_combined_growth()
        cost_of_equity = self.cost_of_equity()
        realistic_growth_rate = max(min(historical_growth, rolling_average_growth, combined_growth), 0.02)
        optimal_growth_rate = min(max(historical_growth, rolling_average_growth, combined_growth), cost_of_equity * 0.9)
        return {
            'historical_growth': historical_growth,
            'rolling_average_growth': rolling_average_growth,
            'combined_growth': combined_growth,
            'realistic_growth_rate': realistic_growth_rate,
            'optimal_growth_rate': optimal_growth_rate
        }


    def get_value(self):
        if not self.check():
            print("Dividend Payout Ratio is too low to calculate DDM value.")
            return np.nan
        return self.__get_ddm_value()
    
    def cost_of_equity(self):
        dcf = DCFValuation(self.stock, 0.02)
        return dcf.cost_of_equity()
    
    def __get_current_dividend(self):
        dividends = self.stock.dividends
        current_dividend = dividends.iloc[-1]

        return current_dividend

    def __get_ddm_value(self):
        current_dividend = self.__get_current_dividend()
        if pd.isna(current_dividend):
            return np.nan

        cost_of_equity = self.cost_of_equity()
        expected_growth_rate = self.__get_realistic_growth_rate().get('realistic_growth_rate')
        optimal_growth_rate = self.__get_realistic_growth_rate().get('optimal_growth_rate')
        if pd.isna(expected_growth_rate) or cost_of_equity <= expected_growth_rate:
            expected_growth_rate = 0.8 * cost_of_equity
        expected_dividend_next_year = current_dividend * (1 + expected_growth_rate)

        intrinsic_value_min = expected_dividend_next_year / (cost_of_equity - expected_growth_rate)
        intrinsic_value_max = expected_dividend_next_year / (cost_of_equity - optimal_growth_rate)
        return [intrinsic_value_min, intrinsic_value_max]

    def get_valuation_ratios(self):
        ddm_valuation_ratio_min = self.__get_ddm_value()[0] / self.stock.df.get('marketCap')
        ddm_valuation_ratio_max = self.__get_ddm_value()[1] / self.stock.df.get('marketCap')    
        expected_growth_rate = self.__get_realistic_growth_rate().get('realistic_growth_rate')
        
        return [ddm_valuation_ratio_min, ddm_valuation_ratio_max, expected_growth_rate]

    def test(self):
        try:
            current_stock_price = self.__get_current_stock_price()
            expected_growth_rate = self.__get_realistic_growth_rate().get('realistic_growth_rate')
            required_rate_of_return = self.cost_of_equity()
            current_dividend = self.__get_current_dividend()
            intrinsic_value_min, intrinsic_value_max = self.__get_ddm_value()[0], self.__get_ddm_value()[1]
            print(f"Ticker: {self.stock.ticker}")
            print(f"Current Dividend: {current_dividend}")
            print(f"Current Stock Price: {current_stock_price}")
            print(f"Expected Growth Rate: {expected_growth_rate:.4f}")
            print(f"Required Rate of Return: {required_rate_of_return:.4f}")
            print(f"Intrinsic Value min: {intrinsic_value_min:.2f}")
            print(f"Intrinsic Value max: {intrinsic_value_max:.2f}")
            print(f"Dividend Payout Ratio: {self.dividend_payout_ratio:.2f}")
        except Exception as e:
            print(f"Failed to obtain data for {self.ticker}.")
            print(e)

# %%
import yfinance as yf
import pandas as pd
import numpy as np


# Valuation object to handle the traditional dcf valuation methods
class Valuation:
    def __init__(self, stock):
        self.stock = stock

    def get_value(self):
        raise NotImplementedError("Subclasses should implement this method")

    def test(self):
        raise NotImplementedError("Subclasses should implement this method")
    
    def get_valuation_ratios(self):
        raise NotImplementedError("Subclasses should implement this method")


class DCFValuation(Valuation):
    def __init__(self, stock, inflation_rate, periods=4):
        super().__init__(stock)
        self.inflation_rate = inflation_rate
        self.periods = periods
        self.last_sp500_return = self.__get_market_rate_of_return()
        self.risk_free_rate = self.__get_risk_free_rate()

    def __get_treasury_yields(self):
        treasury_ticker = '^TNX'
        treasury_data = yf.Ticker(treasury_ticker)
        treasury_yield = treasury_data.history(period='5d')['Close'].iloc[-1]
        risk_free_rate = treasury_yield / 100
        return risk_free_rate

    def __get_market_rate_of_return(self):
        sp500 = yf.Ticker('^GSPC')
        sp500_data = sp500.history(period='10y')
        sp500_data['Yearly Return'] = sp500_data['Close'].pct_change(periods=252)
        yearly_returns = sp500_data['Yearly Return'].dropna()
        avg_annual_return = yearly_returns.mean()
        return avg_annual_return

    def __get_risk_free_rate(self):
        raw_risk_free_rate = self.__get_treasury_yields()
        nominal_risk_free_rate = (1 + raw_risk_free_rate) * (1 + self.inflation_rate) - 1
        return nominal_risk_free_rate

    def __get_cash_flows(self):
        try:
            cash_flows = self.stock.cash_flow.loc['Free Cash Flow'].iloc[:self.periods].to_numpy()
        except KeyError:
            cash_flows = self.stock.cash_flow.loc['Operating Cash Flow'].iloc[:self.periods].to_numpy()
        
        # Ensure cash flows are non-negative
        cash_flows = np.where(cash_flows < 0, 0, cash_flows)
        return list(cash_flows)

    def __get_growth_rate(self):
        cash_flows = self.__get_cash_flows()
        growth_rates = []
        for i in range(1, len(cash_flows)):
            yearOne, yearTwo = cash_flows[i - 1], cash_flows[i]
            if yearOne <= 0 or yearTwo <= 0:
                continue
            curr_growth_rate = (yearTwo - yearOne) / yearOne
            growth_rates.append(curr_growth_rate)
        if not growth_rates:
            return 0
        avg_growth_rate = sum(growth_rates) / len(growth_rates)
        # We cap at 20% (to be prudent)
        return min(max(avg_growth_rate, 0), 0.20)



    def cost_of_equity(self):
        beta = self.stock.df.get('beta', 1)
        nominal_risk_free_rate = self.risk_free_rate
        market_rate_of_return = self.last_sp500_return
        cost_of_equity = nominal_risk_free_rate + beta * (market_rate_of_return - nominal_risk_free_rate)
        return cost_of_equity

    def cost_of_debt(self):
        credit_spread = self.__get_credit_spread()
        tax_rate = self.__get_tax_rate()
        nominal_risk_free_rate = self.risk_free_rate    
        current_credit_spread = credit_spread[0]
        cost_of_debt = (nominal_risk_free_rate + current_credit_spread) * (1 - tax_rate)
        return cost_of_debt
    
    def get_wacc(self):
        tax_rate = self.__get_tax_rate()
        cost_of_equity = self.cost_of_equity()
        cost_of_debt = self.cost_of_debt()
        equity_weight, debt_weight = self.get_weights()
        wacc = (equity_weight * cost_of_equity) + (debt_weight * cost_of_debt * (1 - tax_rate))
        return max(wacc, 0)

    def get_weights(self):
        def get_market_value_of_equity():
            market_cap = self.stock.df.get('marketCap')
            return market_cap
        
        def get_market_cap_of_debt():
            total_debt = self.stock.balance_sheet.loc['Total Debt'].iloc[0]
            return total_debt

        equity = get_market_value_of_equity()
        total_debt = get_market_cap_of_debt()
        equity_weight = equity / (equity + total_debt)
        debt_weight = total_debt / (equity + total_debt)
        return equity_weight, debt_weight
    
    def __get_tax_rate(self):
        return self.stock.income_stmt.loc['Tax Rate For Calcs'].iloc[0]
    
    def __get_credit_spread(self):
        real_risk_free_rate = self.risk_free_rate
        interest_expense = self.stock.obtain_interest_expense(periods=self.periods)
        total_debt = self.stock.balance_sheet.loc['Total Debt'].iloc[:self.periods].to_numpy()
        average_interest_expense = [self.risk_free_rate if interest_expense[i] == 0 else interest_expense[i] / total_debt[i] for i in range(len(total_debt))]
        credit_spread = [avg_interest - real_risk_free_rate for avg_interest in average_interest_expense]
        return credit_spread

    def __calculate_terminal_value(self, growth_rate, wacc):
        final_year_fcf = self.stock.cash_flow.loc['Free Cash Flow'].iloc[0]
        perpetuity_growth_rate = 0 if growth_rate < 0 else 0.02
        if wacc <= perpetuity_growth_rate:
            wacc = perpetuity_growth_rate + 0.01
        terminal_value = (final_year_fcf * (1 + perpetuity_growth_rate)) / (wacc - perpetuity_growth_rate)
        return terminal_value

    def get_valuation_ratios(self):
        dcf_valuation_ratio = self.__get_dcf_value() / self.stock.df.get('marketCap')
        free_cash_flow = self.stock.cash_flow.loc['Free Cash Flow'].iloc[:self.periods].to_numpy()
        if len(free_cash_flow) < self.periods:
            free_cash_flow = np.append(free_cash_flow, free_cash_flow[-1] * self.periods - len(free_cash_flow))
        cash_flows = free_cash_flow[:4]
        growth_rate = self.__get_growth_rate()
        wacc = self.get_wacc()
        cost_of_equity = self.cost_of_equity()
        cost_of_debt = self.cost_of_debt()
        return [dcf_valuation_ratio, *cash_flows, growth_rate, wacc, cost_of_equity, cost_of_debt]

    def __get_dcf_value(self):
        growth_rate = self.__get_growth_rate()
        wacc = self.get_wacc()
        cash_flows = self.__get_cash_flows()
        forecasted_fcfs = [cash_flows[-1] * ((1 + growth_rate) ** (i + 1)) for i in range(self.periods)]
        discounted_fcfs = [fcf / ((1 + wacc) ** (i + 1)) for i, fcf in enumerate(forecasted_fcfs)]
        terminal_value = self.__calculate_terminal_value(growth_rate, wacc)
        discounted_terminal_value = terminal_value / ((1 + wacc) ** self.periods)
        dcf_value = sum(discounted_fcfs) + discounted_terminal_value

        print(f"Growth Rate: {growth_rate}")
        print(f"WACC: {wacc}")
        print(f"Cash Flows: {cash_flows}")
        print(f"Forecasted FCFs: {forecasted_fcfs}")
        print(f"Discounted FCFs: {discounted_fcfs}")
        print(f"Terminal Value: {terminal_value}")
        print(f"Discounted Terminal Value: {discounted_terminal_value}")
        print(f"DCF Value: {dcf_value}")
        return dcf_value

    def get_value(self):
        return self.__get_dcf_value()

    def test(self):
        try:
            market_cap = self.stock.df.get('marketCap')
            wacc = self.get_wacc()
            growth_rate = self.__get_growth_rate()
            terminal_value = self.__calculate_terminal_value(growth_rate, wacc)
            dcf_value = self.__get_dcf_value()
            print(f"Ticker: {self.stock.ticker}")
            print(f"Risk Free Rate: {self.risk_free_rate}")
            print(f"Market Cap: {market_cap}")
            print(f"WACC: {wacc}")
            print(f"Growth Rate: {growth_rate}")
            print(f"Terminal Value: {terminal_value}")
            print(f"DCF Value: {dcf_value}")
            print(f"Valuation ratio: {dcf_value / market_cap:.2f}")
        except Exception as e:
            print(f"Failed to obtain data for {self.ticker}.")
            print(e)


class DDMValuation(Valuation):
    def __init__(self, stock):
        super().__init__(stock)
        self.dividend_payout_ratio = self.__calculate_dividend_payout_ratio()

    def __calculate_dividend_payout_ratio(self):
        div_yield = self.stock.df.get('dividendYield', 0) * 100
        pe_ratio = self.stock.df.get('trailingPE', 0)
        dividend_payout_ratio = div_yield / (pe_ratio + 1e-10)
        return 0 if pd.isna(dividend_payout_ratio) else dividend_payout_ratio
    
    def check(self):
        return self.dividend_payout_ratio > 0.15

    def __get_current_stock_price(self):
        return self.stock.df.get('previousClose')
    
    def __calculate_historical_growth(self, periods=0):
        pct_changes = self.stock.dividends.pct_change(periods=periods) if periods else self.stock.dividends.pct_change()
        lower, upper = pct_changes.quantile(0.025), pct_changes.quantile(0.975)
        filtered_pct_changes = pct_changes[(pct_changes >= lower) & (pct_changes <= upper)]
        return filtered_pct_changes.mean()

    def __calculate_rolling_average_growth(self, window=10):
        rolling_growth = self.stock.dividends.pct_change().rolling(window=window).mean()
        return rolling_growth.mean()

    def __calculate_combined_growth(self, short_period=5, long_period=10):
        short_term_growth = self.__calculate_historical_growth(periods=short_period)
        long_term_growth = self.__calculate_historical_growth(periods=long_period)
        combined_growth = (0.4 * short_term_growth) + (0.6 * long_term_growth)
        return combined_growth

    def __get_realistic_growth_rate(self):
        historical_growth = self.__calculate_historical_growth()
        rolling_average_growth = self.__calculate_rolling_average_growth()
        combined_growth = self.__calculate_combined_growth()
        cost_of_equity = self.cost_of_equity()
        realistic_growth_rate = max(min(historical_growth, rolling_average_growth, combined_growth), 0.02)
        optimal_growth_rate = min(max(historical_growth, rolling_average_growth, combined_growth), cost_of_equity * 0.9)
        return {
            'historical_growth': historical_growth,
            'rolling_average_growth': rolling_average_growth,
            'combined_growth': combined_growth,
            'realistic_growth_rate': realistic_growth_rate,
            'optimal_growth_rate': optimal_growth_rate
        }

    def get_value(self):
        if not self.check():
            print("Dividend Payout Ratio is too low to calculate DDM value.")
            return np.nan
        return self.__get_ddm_value()
    
    def cost_of_equity(self):
        dcf = DCFValuation(self.stock, 0.02)
        return dcf.cost_of_equity()
    
    def __get_current_dividend(self):
        dividends = self.stock.dividends
        current_dividend = dividends.iloc[-1]
        return current_dividend

    def __get_ddm_value(self):
        current_dividend = self.__get_current_dividend()
        if pd.isna(current_dividend):
            return np.nan

        cost_of_equity = self.cost_of_equity()
        growth_data = self.__get_realistic_growth_rate()
        expected_growth_rate = growth_data.get('realistic_growth_rate')
        optimal_growth_rate = growth_data.get('optimal_growth_rate')

        if pd.isna(expected_growth_rate) or cost_of_equity <= expected_growth_rate:
            expected_growth_rate = 0.8 * cost_of_equity

        expected_dividend_next_year = current_dividend * (1 + expected_growth_rate)
        intrinsic_value_min = expected_dividend_next_year / (cost_of_equity - expected_growth_rate)
        intrinsic_value_max = expected_dividend_next_year / (cost_of_equity - optimal_growth_rate)
        return [intrinsic_value_min, intrinsic_value_max]

    def get_valuation_ratios(self):
        ddm_values = self.__get_ddm_value()
        ddm_valuation_ratio_min = ddm_values[0] / self.stock.df.get('marketCap')
        ddm_valuation_ratio_max = ddm_values[1] / self.stock.df.get('marketCap')    
        expected_growth_rate = self.__get_realistic_growth_rate().get('realistic_growth_rate')
        return [ddm_valuation_ratio_min, ddm_valuation_ratio_max, expected_growth_rate]

    def test(self):
        try:
            current_stock_price = self.__get_current_stock_price()
            growth_data = self.__get_realistic_growth_rate()
            expected_growth_rate = growth_data.get('realistic_growth_rate')
            required_rate_of_return = self.cost_of_equity()
            current_dividend = self.__get_current_dividend()
            intrinsic_value_min, intrinsic_value_max = self.__get_ddm_value()
            print(f"Ticker: {self.stock.ticker}")
            print(f"Current Dividend: {current_dividend}")
            print(f"Current Stock Price: {current_stock_price}")
            print(f"Expected Growth Rate: {expected_growth_rate:.4f}")
            print(f"Required Rate of Return: {required_rate_of_return:.4f}")
            print(f"Intrinsic Value min: {intrinsic_value_min:.2f}")
            print(f"Intrinsic Value max: {intrinsic_value_max:.2f}")
            print(f"Dividend Payout Ratio: {self.dividend_payout_ratio:.2f}")
        except Exception as e:
            print(f"Failed to obtain data for {self.stock.ticker}.")
            print(e)

# %%
import yfinance as yf
import pandas as pd
import numpy as np

class Stock:
    def __init__(self, ticker, inflation_rate=0.0160, years=1, isQuarter=False):
        self.ticker = ticker
        self.years = years
        self.isQuarter = isQuarter
        self.inflation_rate = inflation_rate
        self.stock = yf.Ticker(ticker)
        self.df = self.stock.info
        if self.df is None:
            raise ValueError(f"Failed to get data for {self.ticker}.")
        self.income_stmt = self.stock.financials
        self.balance_sheet = self.stock.balance_sheet
        self.cash_flow = self.stock.cashflow
        if self.income_stmt.empty or self.balance_sheet.empty or self.cash_flow.empty:
            raise ValueError(f"Failed to get financial data for {self.ticker}.")
        self.dividends = self.stock.dividends
        self.dcf_valuation = DCFValuation(self, self.inflation_rate)
        self.ddm_valuation = DDMValuation(self)
        self.market_cap = self.df.get('marketCap')

        self.validate_data()

    def validate_data(self):
        if not self.ticker or not isinstance(self.ticker, str):
            raise ValueError("Ticker must be a non-empty string.")
        if not isinstance(self.inflation_rate, (int, float)):
            raise ValueError("Inflation rate must be a number.")

    def get_history(self, period="max"):
        try:
            return self.stock.history(period=period)
        except Exception as e:
            print(f"Failed to get history for {self.ticker}: {e}")
            return pd.DataFrame()

    def refresh_data(self):
        try:
            self.stock = yf.Ticker(self.ticker)
            self.df = self.stock.info
            self.income_stmt = self.stock.financials
            self.balance_sheet = self.stock.balance_sheet
            self.cash_flow = self.stock.cashflow
            self.dividends = self.stock.dividends
            print(f"Data refreshed for {self.ticker}.")
        except Exception as e:
            print(f"Failed to refresh data for {self.ticker}: {e}")

    def get_value(self, attribute, default=None, isBig=False):
        return self.df.get(attribute, default) if not isBig else self.df.get(attribute, default) / 100

    def test(self, fn):
        try:
            data = fn()
            print(data)
        except Exception as e:
            print(f"Failed to execute function for {self.ticker}: {e}")

    # Util methods

    def _get_metric_from_df(self, key, default=0):
        return self.df.get(key, default)

    def _get_metric_from_income_stmt(self, key, default=0):
        try:
            return self.income_stmt.loc[key].iloc[0] / 100
        except KeyError:
            return default

    def _get_metric_from_balance_sheet(self, key, default=0):
        try:
            return self.balance_sheet.loc[key].iloc[0] / 100
        except KeyError:
            return default

    def _get_metric_from_cashflow(self, key, default=0):
        try:
            return self.cash_flow.loc[key].iloc[0] / 100
        except KeyError:
            return default

    def _get_sum_of_keys(self, primary_key, keys):
        try:
            return self.balance_sheet.loc[primary_key].iloc[0]
        except KeyError:
            total = 0
            for key in keys:
                if key in self.balance_sheet.index:
                    total += self.balance_sheet.loc[key].sum()
                else:
                    print(f"Key '{key}' not found in balance sheet.")
            return total

    def _get_ratio(self, numerator, denominator, default=0):
        return numerator / denominator if denominator != 0 else default

    def __str__(self):
        return f"Stock({self.ticker})"


class StockData(Stock):
    def __init__(self, ticker, inflation_rate=0.0160):
        super().__init__(ticker, inflation_rate)

    def build_data(self):
        # Basic financial metrics
        financial_metrics = {
            'Ticker': self.ticker,
            'Market Cap': self.market_cap,
            'Revenue': self.df.get('totalRevenue', 0),
            'Sector': self.df.get('sector', 'Unknown'),
            'Free Cash Flow': self.df.get('freeCashflow', 0),
            'Capital Expenditure': abs(self.__get_cap_ex()),
            'Net Income': self.df.get('netIncomeToCommon', 0),
            'Operating Cash Flow': self._get_metric_from_cashflow('Operating Cash Flow', 0),
            'EBITDA': self.df.get('ebitda', 0)
        }

        current_assets, total_assets = self.__get_assets()
        interest_expense = self.obtain_interest_expense()

        valuation_metrics = self.__get_valuation_metrics(financial_metrics, current_assets, total_assets, interest_expense)
        quality_metrics = self.__get_quality_metrics(financial_metrics, current_assets, total_assets, interest_expense)
        economic_moat_metrics = self.__get_economic_moat_metrics(financial_metrics)
        price_data = self.__get_price_data()

        value_data = {**financial_metrics, **valuation_metrics, **quality_metrics, **economic_moat_metrics, **price_data}

        # Convert to DataFrame
        value_data_df = pd.DataFrame([value_data])

        # List of columns to be divided by 100
        cols_to_divide = ['Market Cap', 'Revenue', 'Free Cash Flow', 'Capital Expenditure', 'Net Income', 'Operating Cash Flow', 'EBITDA', 'DCF Value Billions', 'Operating Cash Flow Billions', 'Retained Earnings Billions', 'Economic Value Added Billions', 'Earnings Power Value']

        # Divide the selected columns by 100
        for col in cols_to_divide:
            if col in value_data_df.columns:
                value_data_df[col] = value_data_df[col] / 1e9

        return value_data_df

    def __get_total_assets(self):
        return self._get_sum_of_keys('Total Assets', [
            'Cash Cash Equivalents And Short Term Investments',
            'Other Short Term Investments',
            'Cash And Cash Equivalents',
            'Cash Equivalents',
            'Cash Financial',
            'Receivables',
            'Other Receivables',
            'Accounts Receivable',
            'Inventory',
            'Other Current Assets',
            'Net PPE',
            'Investments And Advances',
            'Long Term Equity Investment',
            'Investments In Other Ventures Under Equity Method',
            'Goodwill And Other Intangible Assets',
            'Other Intangible Assets',
            'Goodwill',
            'Properties',
            'Machinery Furniture Equipment',
            'Land And Improvements'
        ])

    def __get_current_assets(self):
        return self._get_sum_of_keys('Current Assets', [
            'Cash Cash Equivalents And Short Term Investments',
            'Other Short Term Investments',
            'Cash And Cash Equivalents',
            'Cash Equivalents',
            'Cash Financial',
            'Receivables',
            'Other Receivables',
            'Accounts Receivable',
            'Inventory',
            'Other Current Assets'
        ])

    def __get_assets(self):
        total_assets = self.__get_total_assets()
        current_assets = self.__get_current_assets()
        return current_assets, total_assets

    def __get_valuation_metrics(self, financial_metrics, current_assets, total_assets, interest_expense):
        dcf_value = self.__get_dcf_value()
        if not self.ddm_valuation.check():
            ddm_valuation_ratio_min, ddm_valuation_ratio_max, dividend_expected_growth_rate = 0, 0, 0
        else:
            ddm_valuation_data = self.__get_ddm_values()
            ddm_valuation_ratio_min, ddm_valuation_ratio_max, dividend_expected_growth_rate = ddm_valuation_data

        dcf_valuation_data = self.__get_dcf_values()
        dcf_valuation_ratio, cash_flow1, cash_flow2, cash_flow3, cash_flow4, growth_rate, wacc, cost_of_equity, cost_of_debt = dcf_valuation_data
        strong_buy, buy, hold, sell, strong_sell = self.__parse_analyst_reccomendations()
        equity_weight, debt_weight = self.dcf_valuation.get_weights()

        pe_ratio = self._get_metric_from_df('trailingPE', 0)
        div_yield = self._get_metric_from_df('dividendYield', 0) * 100
        eps_growth = self.__get_eps_growth()
        return {
            'DCF Value Billions': dcf_value,
            'DCF Valuation Ratio': dcf_valuation_ratio,
            'DDM Valuation Ratio Min': ddm_valuation_ratio_min,
            'DDM Valuation Ratio Max': ddm_valuation_ratio_max,
            'Dividend Expected Growth Rate': dividend_expected_growth_rate,
            'P/E Ratio': pe_ratio,
            'P/B Ratio': self._get_metric_from_df('priceToBook', 0),
            'P/S Ratio': self._get_metric_from_df('priceToSalesTrailing12Months', 0),
            'P/FCF Ratio': self._get_ratio(self.market_cap, financial_metrics['Free Cash Flow']),
            'Dividend Yield': div_yield,
            'EPS': self._get_metric_from_df('trailingEps', 0),
            'EPS Growth': eps_growth,
            'Revenue Growth': self.__get_revenue_growth(),
            'PEG Ratio': self._get_ratio(pe_ratio, eps_growth),
            'Cash Flow 1 Billions': cash_flow1,
            'Cash Flow 2 Billions': cash_flow2,
            'Cash Flow 3 Billions': cash_flow3,
            'Cash Flow 4 Billions': cash_flow4,
            'Growth Rate': growth_rate,
            "NCAVPS": self.__get_net_current_asset_value_per_share(),
            'WACC': wacc,
            'Equity Weight': equity_weight,
            'Debt Weight': debt_weight,
            'Cost of Equity': cost_of_equity,
            'Cost of Debt': cost_of_debt,
            'Enterprise to Revenue': self._get_metric_from_df('enterpriseToRevenue', 0),
            'Enterprise to EBITDA': self._get_metric_from_df('enterpriseToEbitda', 0),
            'Total Cash Per Share': self._get_metric_from_df('totalCashPerShare', 0),
            'Interest Expense Billions': interest_expense / 100,
            'Strong Buy': strong_buy,
            'Buy': buy,
            'Hold': hold,
            'Sell': sell,
            'Strong Sell': strong_sell
        }

    def __get_quality_metrics(self, financial_metrics, current_assets, total_assets, interest_expense):
        current_liabilities = self.__get_current_liabilities()
        net_income = financial_metrics['Net Income']
        roe = self.__get_return_on_equity()
        de_ratio = self._get_metric_from_df('debtToEquity', 0)

        return {
            'Net Margin': self._get_ratio(net_income, financial_metrics['Revenue']),
            'Gross Margin': self.__get_gross_margin(),
            'ROA': self._get_metric_from_df('returnOnAssets', 0),
            'ROE': roe,
            'Current Ratio': self._get_ratio(current_assets, current_liabilities),
            'Quick Ratio': self.__get_quick_ratio(),
            'D/E Ratio': de_ratio,
            'Dividend Payout Ratio': self.__calculate_dividend_payout_ratio(),
            'FCF Yield': self._get_ratio(financial_metrics['Free Cash Flow'], self.market_cap) * 100,
            'Capex_to_sales': self._get_ratio(abs(financial_metrics['Capital Expenditure']), financial_metrics['Revenue']),
            'Operating Margin': self.__get_operating_margin(),
            'Debt to Asset Ratio': self._get_ratio(de_ratio, 1 + de_ratio),
            'Equity to Asset Ratio': self.__get_debt_to_asset(),
            'Interest Coverage Ratio': self._get_ratio(financial_metrics['Revenue'], interest_expense),
            'NCAVPS': self.__get_net_current_asset_value_per_share(),
            'ROIC': self.__get_roic(),
            'Altman Z Score': self.__get_altman_z_score(),
            'Operating Cash Flow Billions': financial_metrics['Operating Cash Flow'],
            'Asset Turnover Ratio': self.__get_turnover_ratios()[0],
            'Inventory Turnover Ratio': self.__get_turnover_ratios()[1],
            'Retained Earnings Billions': self.__get_retained_earnings(),
            'Earnings Power Value': self.__get_earnings_power_value()
        }

    def __get_price_data(self):
        current_price = self.get_history(period="1d")['Close'].iloc[-1]
        historical_data = self.get_history(period="1y")

        moving_average_50 = historical_data['Close'].rolling(window=50).mean().iloc[-1]
        moving_average_200 = historical_data['Close'].rolling(window=200).mean().iloc[-1]

        year_high = historical_data['Close'].max()
        year_low = historical_data['Close'].min()

        average_volume_50 = historical_data['Volume'].rolling(window=50).mean().iloc[-1]

        day_high = self.get_history(period="1d")['High'].iloc[-1]
        day_low = self.get_history(period="1d")['Low'].iloc[-1]

        price_data = {
            'Current Price': current_price,
            '50-Day Moving Average': moving_average_50,
            '200-Day Moving Average': moving_average_200,
            '52-Week High': year_high,
            '52-Week Low': year_low,
            'Average Volume (50 days)': average_volume_50,
            'Day High': day_high,
            'Day Low': day_low,
            'Previous Close': historical_data['Close'].iloc[-2],
            'Open': self.get_history(period='1d')['Open'].iloc[-1]
        }
        
        return price_data

    def __get_economic_moat_metrics(self, financial_metrics):
        free_cash_flow = financial_metrics['Free Cash Flow']
        revenue = financial_metrics['Revenue']
        fcf_ratio = self._get_ratio(free_cash_flow, revenue)
        eva = self.__get_eva()
        sgr = self.__get_sgr()

        return {
            'Economic Value Added Billions': eva,
            'FCF Ratio': fcf_ratio,
            'Sustainable Growth Rate': sgr
        }

    def __get_quick_ratio(self):
        quick_ratio = self._get_metric_from_df('quickRatio', 0)
        if quick_ratio == 0:
            inventory = self._get_metric_from_balance_sheet('Inventory', 0)
            current_assets = self.__get_current_assets()
            current_liabilities = self.__get_current_liabilities()
            quick_ratio = self._get_ratio(current_assets - inventory, current_liabilities)
        return quick_ratio
    
    def __get_debt_to_asset(self):
        debt = self._get_metric_from_balance_sheet('Total Debt', 0)
        assets = self._get_metric_from_balance_sheet('Total Assets', 0)
        return self._get_ratio(debt, assets)

    def __get_return_on_equity(self):
        roe = self._get_metric_from_df('returnOnEquity', 0)
        if roe == 0:
            net_income = self._get_metric_from_df('netIncomeToCommon', 0)
            equity = self._get_metric_from_balance_sheet('Total Equity', 0)
            roe = self._get_ratio(net_income, equity)
        return roe

    def __get_gross_margin(self):
        gross_margin = self._get_metric_from_df('grossMargins', 0)
        if gross_margin == 0:
            gross_profit = self._get_metric_from_income_stmt('Gross Profit', 0)
            revenue = self._get_metric_from_df('totalRevenue', 0)
            gross_margin = self._get_ratio(gross_profit, revenue)
        return gross_margin

    def __get_eps_growth(self):
        eps_growth = self._get_metric_from_df('earningsQuarterlyGrowth', 0)
        if eps_growth == 0:
            try:
                eps_diluted_array = self.income_stmt.loc['Diluted EPS'].to_numpy()[:4]
                eps_growth = self._get_ratio(eps_diluted_array[0] - eps_diluted_array[1], eps_diluted_array[1])
            except KeyError:
                return 0
        return eps_growth

    def __get_revenue_growth(self):
        revenue_growth = self._get_metric_from_df('revenueQuarterlyGrowth', 0)
        if revenue_growth == 0:
            try:
                revenue_array = self.income_stmt.loc['Total Revenue'].to_numpy()[:4]
                revenue_growth = self._get_ratio(revenue_array[0] - revenue_array[1], revenue_array[1])
            except KeyError:
                return 0
        return revenue_growth

    def __get_operating_margin(self):
        operating_margin = self._get_metric_from_df('operatingMargins', 0)
        if operating_margin == 0:
            operating_income = self._get_metric_from_income_stmt('Operating Income', 0)
            revenue = self._get_metric_from_df('totalRevenue', 0)
            operating_margin = self._get_ratio(operating_income, revenue)
        return operating_margin

    def __get_roic(self):
        net_income = self._get_metric_from_df('netIncomeToCommon', 0)
        total_assets = self.__get_total_assets()
        current_liabilities = self.__get_current_liabilities()
        return self._get_ratio(net_income, total_assets - current_liabilities)

    def __get_ebit(self):
        ebit = self._get_metric_from_income_stmt('EBIT', 0)
        if ebit == 0:
            net_income = self._get_metric_from_df('netIncomeToCommon', 0)
            special_income_charges = self._get_metric_from_income_stmt('Special Income Charges', 0)
            tax_provision = self._get_metric_from_income_stmt('Tax Provision', 0)
            interest_expense = self.obtain_interest_expense()
            ebit = net_income + interest_expense + tax_provision + special_income_charges
        return ebit

    def __get_earnings_power_value(self):
        ebit = self.__get_ebit()
        tax_rate = self._get_metric_from_income_stmt('Tax Rate For Calcs', 0)
        wacc = self.dcf_valuation.get_wacc()
        epv = self._get_ratio(ebit * (1 - tax_rate), wacc)
        if np.isnan(epv):
            epv = 0
        return epv

    def __get_altman_z_score(self):
        ebit = self.__get_ebit()
        working_capital = self.__get_current_assets() - self.__get_current_liabilities()
        retained_earnings = self.__get_retained_earnings()
        total_assets = self.__get_total_assets()
        total_liabilities = self.__get_total_liabilities()
        sales = self._get_metric_from_df('totalRevenue', 0)
        z = (1.2 * self._get_ratio(working_capital, total_assets) +
             1.4 * self._get_ratio(retained_earnings, total_assets) +
             3.3 * self._get_ratio(ebit, total_assets) +
             0.6 * self._get_ratio(self.market_cap, total_liabilities) +
             1.0 * self._get_ratio(sales, total_assets))
        return z

    def __get_turnover_ratios(self):
        sales = self._get_metric_from_df('totalRevenue', 0)
        total_assets = self.__get_total_assets()
        inventory = self._get_metric_from_balance_sheet('Inventory', 0)
        return self._get_ratio(sales, total_assets), self._get_ratio(sales, inventory)

    def _get_dividend_coverage(self):
        eps = self._get_metric_from_df('trailingEps', 0)
        dps = self._get_metric_from_df('dividendRate', 0)
        return self._get_ratio(eps, dps) if dps else np.nan

    def obtain_interest_expense(self, periods=0):
        interest_keys = ['Interest Expense Non Operating', 'Interest Expense', 'Net Non Operating Interest Income Expense']
        for key in interest_keys:
            if key in self.income_stmt.index:
                if periods > 0:
                    try:
                        interest_expense = self.income_stmt.loc[key].iloc[:periods].to_numpy()
                    except IndexError:
                        print(f"Not enough data for {periods} periods in key '{key}'. Returning available data.")
                        interest_expense = self.income_stmt.loc[key].to_numpy()
                else:
                    interest_expense = self.income_stmt.loc[key].iloc[0]
                return interest_expense
        if periods > 0:
            return np.zeros(periods)
        return 0

    def __get_eva(self):
        net_income = self._get_metric_from_income_stmt('Net Income', 0)
        tax_rate = self._get_metric_from_income_stmt('Tax Rate For Calcs', 0)
        nopat = net_income * (1 - tax_rate)
        invested_capital = self.__get_total_assets() - self.__get_current_liabilities()
        wacc = self.dcf_valuation.get_wacc()
        eva = nopat - (invested_capital * wacc)
        if np.isnan(eva):
            eva = 0
        return eva

    def __calculate_dividend_payout_ratio(self):
        div_yield = self._get_metric_from_df('dividendYield', 0) * 100
        pe_ratio = self._get_metric_from_df('trailingPE', 0)
        if pe_ratio != 0:
            dividend_payout_ratio = div_yield / pe_ratio
        else:
            dividend_payout_ratio = 0
        return dividend_payout_ratio

    def __get_sgr(self):
        roe = self._get_metric_from_df('returnOnEquity', 0)
        dividend_payout_ratio = self.__calculate_dividend_payout_ratio()
        retention_ratio = 1 - dividend_payout_ratio
        sgr = roe * retention_ratio
        return sgr if not pd.isna(sgr) else 0


    def __get_net_current_asset_value_per_share(self):
        current_assets = self.__get_current_assets()
        total_liabilities = self.__get_total_liabilities()
        ordinary_shares_outstanding = self._get_metric_from_balance_sheet('Ordinary Shares Number', 0)
        preferred_shares = self._get_metric_from_balance_sheet('Preferred Shares Number', 0)
        ncavps = self._get_ratio(current_assets - total_liabilities - preferred_shares, ordinary_shares_outstanding)
        return ncavps

    def __get_cap_ex(self):
        return self._get_metric_from_cashflow('Capital Expenditure', 0)

    def __get_ddm_value(self):
        return self.ddm_valuation.get_value()

    def __get_ddm_values(self):
        return self.ddm_valuation.get_valuation_ratios()

    def __get_dcf_value(self):
        return self.dcf_valuation.get_value()

    def __get_dcf_values(self):
        return self.dcf_valuation.get_valuation_ratios()

    def __get_retained_earnings(self):
        retained_earnings_keys = [
            'Retained Earnings',
            'Accumulated Retained Earnings',
            'Undistributed Profits'
        ]
        return self._get_sum_of_keys('Retained Earnings', retained_earnings_keys)

    def __get_current_liabilities(self):
        current_liabilities_keys = [
            'Accounts Payable',
            'Short Term Debt',
            'Other Current Liabilities',
            'Current Deferred Liabilities',
            'Current Deferred Revenue',
            'Current Debt And Capital Lease Obligation',
            'Current Debt',
            'Other Current Borrowings',
            'Commercial Paper',
            'Payables And Accrued Expenses',
            'Payables'
        ]
        return self._get_sum_of_keys('Current Liabilities', current_liabilities_keys)

    def __get_total_liabilities(self):
        total_liabilities_keys = [
            'Total Liabilities Net Minority Interest',
            'Total Non Current Liabilities Net Minority Interest',
            'Other Non Current Liabilities',
            'Trade and Other Payables Non Current',
            'Long Term Debt And Capital Lease Obligation',
            'Long Term Debt',
            'Current Liabilities',
            'Other Current Liabilities',
            'Current Deferred Liabilities',
            'Current Deferred Revenue',
            'Current Debt And Capital Lease Obligation',
            'Current Debt',
            'Other Current Borrowings',
            'Commercial Paper',
            'Payables And Accrued Expenses',
            'Payables',
            'Accounts Payable'
        ]
        return self._get_sum_of_keys('Total Liabilities Net Minority Interest', total_liabilities_keys)

    def __parse_analyst_reccomendations(self):
        try:
            analyst_recommendations = self.stock.recommendations
            strong_buy = analyst_recommendations['strongBuy'].sum()
            buy = analyst_recommendations['buy'].sum()
            hold = analyst_recommendations['hold'].sum()
            sell = analyst_recommendations['sell'].sum()
            strong_sell = analyst_recommendations['strongSell'].sum()
        except KeyError:
            return 0, 0, 0, 0, 0
        return strong_buy, buy, hold, sell, strong_sell

# Assuming DCFValuation and DDMValuation classes are defined elsewhere

# stock = StockData('AAPL')
# data = stock.build_data()
# data.to_csv('dell.csv', index=False)
# print(data)

# %%
# Let us build the tickers
df = pd.read_csv('./ticker_test.csv')

tickers = df['Symbol']
print(tickers)
# Out:
# 0    AAPL
# Name: Symbol, dtype: object

# %%
# Stock portfolio class with threading
import yfinance as yf
import pandas as pd
import time
from concurrent.futures import ThreadPoolExecutor, as_completed

class StockPortfolio:
    def __init__(self, stocks, max_workers=5):
        self.stocks = stocks
        self.max_workers = max_workers
        self.portfolio = self.build_portfolio()
        self.n = len(stocks)

    def build_portfolio(self, save_to_csv=True):
        failed = []
        portfolio = pd.DataFrame()
        print("Building portfolio...")

        with ThreadPoolExecutor(max_workers=self.max_workers) as executor:
            futures = {executor.submit(self.build_stock_data, stock): stock for stock in self.stocks}

            for future in as_completed(futures):
                stock = futures[future]
                try:
                    stock_data = future.result()
                    if stock_data is not None:
                        portfolio = pd.concat([portfolio, stock_data], ignore_index=True)
                except Exception as e:
                    print(f"Failed to obtain data for {stock}. Error: {e}")
                    failed.append(stock)

        if save_to_csv:
            # Pay attention to output file -> don't overwrite
            portfolio.to_csv('test_data.csv', index=False)
        return portfolio

    def build_stock_data(self, ticker):
        try:
            stock = StockData(ticker)
            print(stock)
            stock_data = stock.build_data()
            return stock_data
        except Exception as e:
            print(f"Failed to obtain data for {ticker}. Error: {e}")
            return None

    def get_portfolio(self):
        return self.portfolio
    
    def __str__(self):
        return f"StockPortfolio({self.stocks})"
    
stock_portfolio = StockPortfolio(tickers)
# print(stock_portfolio.get_portfolio())
# Out:
# Building portfolio...
# Stock(AAPL)
# Growth Rate: 0
# WACC: 0.12134315406777503
# Cash Flows: [99584000000.0, 111443000000.0, 92953000000.0, 73365000000.0]
# Forecasted FCFs: [73365000000.0, 73365000000.0, 73365000000.0, 73365000000.0]
# Discounted FCFs: [65426002498.75495, 58346102405.33073, 52032334788.57466, 46401794669.02937]
# Terminal Value: 1002294441438.7327
# Discounted Terminal Value: 633929814891.9724
# DCF Value: 856136049253.6621
# Growth Rate: 0
# WACC: 0.12134315406777503
# Cash Flows: [99584000000.0, 111443000000.0, 92953000000.0, 73365000000.0]
# Forecasted FCFs: [73365000000.0, 73365000000.0, 73365000000.0, 73365000000.0]
# Discounted FCFs: [65426002498.75495, 58346102405.33073, 52032334788.57466, 46401794669.02937]
# Terminal Value: 1002294441438.7327
# Discounted Terminal Value: 633929814891.9724
# DCF Value: 856136049253.6621
# Failed to obtain data for AAPL. Error: 'Ticker' object has no attribute 'get_history'

# %%
# Let's define the stock portfolio class

class StockPortfolio:
    def __init__(self, stocks):
        self.stocks = stocks
        self.n = len(stocks) 
        self.portfolio = self.build_portfolio()


    def build_portfolio(self, save_to_csv=True):
        failed = []
        portfolio = pd.DataFrame()
        print("Building portfolio...")
        for i, stock in enumerate(self.stocks):
            print(f"Building data for {stock}... ({i+1} / {self.n})")  # Correctly using i and self.n
            try:
                stock_data = StockData(stock)
                stock_data_df = stock_data.build_data()
                if stock_data_df.empty:
                    print(f"Failed to obtain data for {stock}.")
                    failed.append(stock)
                else:
                    portfolio = pd.concat([portfolio, stock_data_df], ignore_index=True)
            except Exception as e:
                print(f"Failed to obtain data for {stock}.")
                print(e)
                failed.append(stock)
        
        if save_to_csv:
            portfolio.to_csv('test_data1.csv', index=False)
        
        print(f"Failed to fetch data for: {failed}")
        return portfolio

    def get_portfolio(self):
        return self.portfolio

    def __str__(self):
        return f"StockPortfolio({self.stocks})"


# Run the stock portfolio class
tickers = ["TSLA"]
stock_portfolio = StockPortfolio(tickers)
# Out:
# Building portfolio...
# Building data for TSLA... (1 / 1)
# Growth Rate: 0
# WACC: 0.18198697002284436
# Cash Flows: [4357000000.0, 7552000000.0, 3483000000.0, 2701000000.0]
# Forecasted FCFs: [2701000000.0, 2701000000.0, 2701000000.0, 2701000000.0]
# Discounted FCFs: [2285135173.6540694, 1933299800.7667582, 1635635459.4411416, 1383801599.276115]
# Terminal Value: 27435169627.367317
# Discounted Terminal Value: 14055842875.513659
# DCF Value: 21293714908.65174
# Growth Rate: 0
# WACC: 0.18198697002284436
# Cash Flows: [4357000000.0, 7552000000.0, 3483000000.0, 2701000000.0]
# Forecasted FCFs: [2701000000.0, 2701000000.0, 2701000000.0, 2701000000.0]
# Discounted FCFs: [2285135173.6540694, 1933299800.7667582, 1635635459.4411416, 1383801599.276115]
# Terminal Value: 27435169627.367317
# Discounted Terminal Value: 14055842875.513659
# DCF Value: 21293714908.65174
# Failed to fetch data for: []

# %%
# Set up the API request
import requests
api_key = "67deec4f33msh0943ba7741c6d31p1f00f3jsn3e8d30d8d661"
headers = {
    'x-rapidapi-host': "morning-star.p.rapidapi.com",
    'x-rapidapi-key': api_key
}

# Map to performance ID in MorningStar
def map_to_morningstar_id(ticker):
    url = "https://morning-star.p.rapidapi.com/market/v2/auto-complete"
    queryString = {"q": ticker}
    res = requests.get(url, headers=headers, params=queryString).json()
    # print(res['results'])
    performanceId = res['results'][0]['performanceId']
    if performanceId == None:
        performanceId = res['results'][1]['performanceId']
    return performanceId

# Obtain fair value as judged by MorningStar
def get_fair_value(ticker):
    url = "https://morning-star.p.rapidapi.com/stock/v2/get-price-fair-value"
    performanceId = map_to_morningstar_id(ticker)
    # print(performanceId)
    queryString = {"performanceId": performanceId}
    res = requests.get(url, headers=headers, params=queryString).json()["chart"]["chartDatums"]["recent"]["latestFairValue"]
    return res

# %%
# Now let's join the value data to the data frame
def join_fair_value(sp500_value):
    for i, ticker in enumerate(sp500_value['Ticker']):
        print(f'Obtaining fair value for {ticker} ({i+1}/{len(sp500_value)})')
        try:
            fair_value = get_fair_value(ticker)
            sp500_value.loc[sp500_value['Ticker'] == ticker, 'Fair Value'] = fair_value
        except Exception as e:
            print(f'Failed to obtain fair value for {ticker}')
            print(e)
sp500_value = pd.read_csv('./portfolio_value_data.csv')
join_fair_value(sp500_value)

# Save the DataFrame to a CSV file
sp500_value.to_csv('./portfolio_value_fair_value_data.csv', index=False)
# Out:
# Obtaining fair value for AAPL (1/4981)
# Obtaining fair value for AMZN (2/4981)
# Obtaining fair value for GOOG (3/4981)
# Obtaining fair value for MSFT (4/4981)
# Obtaining fair value for 2222.SR (5/4981)
# Failed to obtain fair value for 2222.SR
# list index out of range
# Obtaining fair value for TSLA (6/4981)
# Obtaining fair value for BRK-A (7/4981)
# Failed to obtain fair value for BRK-A
# list index out of range
# Obtaining fair value for NVDA (8/4981)
# Obtaining fair value for TSM (9/4981)
# Obtaining fair value for UNH (10/4981)
# Obtaining fair value for TCEHY (11/4981)
# Obtaining fair value for V (12/4981)
# Obtaining fair value for WMT (13/4981)
# Obtaining fair value for JNJ (14/4981)
# Obtaining fair value for JPM (15/4981)
# Obtaining fair value for 005930.KS (16/4981)
# Failed to obtain fair value for 005930.KS
# list index out of range
# Obtaining fair value for NSRGY (17/4981)
# Obtaining fair value for PG (18/4981)
# Obtaining fair value for XOM (19/4981)
# Obtaining fair value for RHHBY (20/4981)
# Obtaining fair value for HD (21/4981)
# Obtaining fair value for CVX (22/4981)
# Obtaining fair value for 600519.SS (23/4981)
# Failed to obtain fair value for 600519.SS
# list index out of range
# Obtaining fair value for LVMUY (24/4981)
# Obtaining fair value for BAC (25/4981)
# Obtaining fair value for MA (26/4981)
# Obtaining fair value for ABBV (27/4981)
# Obtaining fair value for LLY (28/4981)
# Obtaining fair value for PFE (29/4981)
# Obtaining fair value for KO (30/4981)
# Obtaining fair value for ASML (31/4981)
# Obtaining fair value for BHP (32/4981)
# Obtaining fair value for NVO (33/4981)
# Obtaining fair value for DIS (34/4981)
# Obtaining fair value for COST (35/4981)
# Obtaining fair value for 1398.HK (36/4981)
# Failed to obtain fair value for 1398.HK
# list index out of range
# Obtaining fair value for AVGO (37/4981)
# Obtaining fair value for CSCO (38/4981)
# Obtaining fair value for BABA (39/4981)
# Obtaining fair value for PEP (40/4981)
# Obtaining fair value for TM (41/4981)
# Obtaining fair value for VZ (42/4981)
# Obtaining fair value for TMO (43/4981)
# Obtaining fair value for RELIANCE.NS (44/4981)
# Failed to obtain fair value for RELIANCE.NS
# list index out of range
# Obtaining fair value for ORCL (45/4981)
# Obtaining fair value for ABT (46/4981)
# Obtaining fair value for OR.PA (47/4981)
# Failed to obtain fair value for OR.PA
# list index out of range
# Obtaining fair value for CMCSA (48/4981)
# Obtaining fair value for ACN (49/4981)
# Obtaining fair value for MRK (50/4981)
# Obtaining fair value for ADBE (51/4981)
# Obtaining fair value for CRM (52/4981)
# Obtaining fair value for DHR (53/4981)
# Obtaining fair value for RYDAF (54/4981)
# Obtaining fair value for AZN (55/4981)
# Obtaining fair value for WFC (56/4981)
# Obtaining fair value for NVS (57/4981)
# Obtaining fair value for NKE (58/4981)
# Obtaining fair value for INTC (59/4981)
# Obtaining fair value for CICHY (60/4981)
# Obtaining fair value for 300750.SZ (61/4981)
# Failed to obtain fair value for 300750.SZ
# list index out of range
# Obtaining fair value for UPS (62/4981)
# Obtaining fair value for MCD (63/4981)
# Obtaining fair value for AMD (64/4981)
# Obtaining fair value for UNP (65/4981)
# Obtaining fair value for QCOM (66/4981)
# Obtaining fair value for T (67/4981)
# Obtaining fair value for ACGBY (68/4981)
# Obtaining fair value for 3968.HK (69/4981)
# Failed to obtain fair value for 3968.HK
# list index out of range
# Obtaining fair value for SCHW (70/4981)
# Obtaining fair value for TMUS (71/4981)
# Obtaining fair value for NEE (72/4981)
# Obtaining fair value for TXN (73/4981)
# Obtaining fair value for RY (74/4981)
# Obtaining fair value for MS (75/4981)
# Obtaining fair value for LOW (76/4981)
# Obtaining fair value for NFLX (77/4981)
# Obtaining fair value for LIN (78/4981)
# Obtaining fair value for PRX.AS (79/4981)
# Failed to obtain fair value for PRX.AS
# list index out of range
# Obtaining fair value for BMY (80/4981)
# Obtaining fair value for RTX (81/4981)
# Obtaining fair value for MDT (82/4981)
# Obtaining fair value for TD (83/4981)
# Obtaining fair value for TCS.NS (84/4981)
# Failed to obtain fair value for TCS.NS
# list index out of range
# Obtaining fair value for PM (85/4981)
# Obtaining fair value for CVS (86/4981)
# Obtaining fair value for BACHF (87/4981)
# Obtaining fair value for HESAF (88/4981)
# Obtaining fair value for SPGI (89/4981)
# Obtaining fair value for PNGAY (90/4981)
# Obtaining fair value for 0941.HK (91/4981)
# Failed to obtain fair value for 0941.HK
# list index out of range
# Obtaining fair value for SAP (92/4981)
# Obtaining fair value for AXP (93/4981)
# Obtaining fair value for TTE (94/4981)
# Obtaining fair value for AMGN (95/4981)
# Obtaining fair value for HSBC (96/4981)
# Obtaining fair value for CBA.AX (97/4981)
# Failed to obtain fair value for CBA.AX
# list index out of range
# Obtaining fair value for SNY (98/4981)
# Obtaining fair value for HON (99/4981)
# Obtaining fair value for SONY (100/4981)
# Obtaining fair value for COP (101/4981)
# Obtaining fair value for AAIGF (102/4981)
# Obtaining fair value for INTU (103/4981)
# Obtaining fair value for DE (104/4981)
# Obtaining fair value for LMT (105/4981)
# Obtaining fair value for CAT (106/4981)
# Obtaining fair value for BUD (107/4981)
# Obtaining fair value for SIEGY (108/4981)
# Obtaining fair value for PYPL (109/4981)
# Obtaining fair value for UL (110/4981)
# Obtaining fair value for GS (111/4981)
# Obtaining fair value for RIO (112/4981)
# Obtaining fair value for PLD (113/4981)
# Obtaining fair value for CDI.PA (114/4981)
# Failed to obtain fair value for CDI.PA
# list index out of range
# Obtaining fair value for IBM (115/4981)
# Obtaining fair value for HDB (116/4981)
# Obtaining fair value for AMT (117/4981)
# Obtaining fair value for AMAT (118/4981)
# Obtaining fair value for MPNGF (119/4981)
# Obtaining fair value for C (120/4981)
# Obtaining fair value for BLK (121/4981)
# Obtaining fair value for NPPXF (122/4981)
# Obtaining fair value for DEO (123/4981)
# Obtaining fair value for 2010.SR (124/4981)
# Failed to obtain fair value for 2010.SR
# list index out of range
# Obtaining fair value for INFY (125/4981)
# Obtaining fair value for GSK (126/4981)
# Obtaining fair value for 1120.SR (127/4981)
# Failed to obtain fair value for 1120.SR
# list index out of range
# Obtaining fair value for NOW (128/4981)
# Obtaining fair value for EQNR (129/4981)
# Obtaining fair value for BA (130/4981)
# Obtaining fair value for GE (131/4981)
# Obtaining fair value for CHTR (132/4981)
# Obtaining fair value for 000858.SZ (133/4981)
# Failed to obtain fair value for 000858.SZ
# list index out of range
# Obtaining fair value for VOW3.DE (134/4981)
# Failed to obtain fair value for VOW3.DE
# list index out of range
# Obtaining fair value for ISRG (135/4981)
# Obtaining fair value for ABNB (136/4981)
# Obtaining fair value for TGT (137/4981)
# Obtaining fair value for SBGSF (138/4981)
# Obtaining fair value for VALE (139/4981)
# Obtaining fair value for SYK (140/4981)
# Obtaining fair value for CSL.AX (141/4981)
# Failed to obtain fair value for CSL.AX
# list index out of range
# Obtaining fair value for BTI (142/4981)
# Obtaining fair value for SBUX (143/4981)
# Obtaining fair value for BP (144/4981)
# Obtaining fair value for MO (145/4981)
# Obtaining fair value for ALIZF (146/4981)
# Obtaining fair value for EL (147/4981)
# Obtaining fair value for 002594.SZ (148/4981)
# Failed to obtain fair value for 002594.SZ
# list index out of range
# Obtaining fair value for EADSF (149/4981)
# Obtaining fair value for DTE.DE (150/4981)
# Failed to obtain fair value for DTE.DE
# list index out of range
# Obtaining fair value for CB (151/4981)
# Obtaining fair value for ENB (152/4981)
# Obtaining fair value for PBR (153/4981)
# Obtaining fair value for ZTS (154/4981)
# Obtaining fair value for ADP (155/4981)
# Obtaining fair value for CNI (156/4981)
# Obtaining fair value for MRK.DE (157/4981)
# Failed to obtain fair value for MRK.DE
# list index out of range
# Obtaining fair value for BNS (158/4981)
# Obtaining fair value for MDLZ (159/4981)
# Obtaining fair value for CME (160/4981)
# Obtaining fair value for GLCNF (161/4981)
# Obtaining fair value for 1180.SR (162/4981)
# Failed to obtain fair value for 1180.SR
# list index out of range
# Obtaining fair value for MMM (163/4981)
# Obtaining fair value for BKNG (164/4981)
# Obtaining fair value for BAM (165/4981)
# Obtaining fair value for HCA (166/4981)
# Obtaining fair value for DUK (167/4981)
# Obtaining fair value for BX (168/4981)
# Obtaining fair value for USB (169/4981)
# Obtaining fair value for MUFG (170/4981)
# Obtaining fair value for MU (171/4981)
# Obtaining fair value for TFC (172/4981)
# Obtaining fair value for ADI (173/4981)
# Obtaining fair value for 600900.SS (174/4981)
# Failed to obtain fair value for 600900.SS
# list index out of range
# Obtaining fair value for ESLOF (175/4981)
# Obtaining fair value for PNC (176/4981)
# Obtaining fair value for AI.PA (177/4981)
# Failed to obtain fair value for AI.PA
# list index out of range
# Obtaining fair value for IDEXY (178/4981)
# Obtaining fair value for MMC (179/4981)
# Obtaining fair value for BMO (180/4981)
# Obtaining fair value for CSUAY (181/4981)
# Obtaining fair value for CSX (182/4981)
# Obtaining fair value for KDDIF (183/4981)
# Obtaining fair value for CCI (184/4981)
# Obtaining fair value for TJX (185/4981)
# Obtaining fair value for GILD (186/4981)
# Obtaining fair value for BDX (187/4981)
# Obtaining fair value for KER.PA (188/4981)
# Failed to obtain fair value for KER.PA
# list index out of range
# Obtaining fair value for SO (189/4981)
# Obtaining fair value for CI (190/4981)
# Obtaining fair value for FMX (191/4981)
# Obtaining fair value for NAB.AX (192/4981)
# Failed to obtain fair value for NAB.AX
# list index out of range
# Obtaining fair value for 601658.SS (193/4981)
# Failed to obtain fair value for 601658.SS
# list index out of range
# Obtaining fair value for REGN (194/4981)
# Obtaining fair value for ICE (195/4981)
# Obtaining fair value for BBCA.JK (196/4981)
# Failed to obtain fair value for BBCA.JK
# list index out of range
# Obtaining fair value for CP (197/4981)
# Obtaining fair value for SHOP (198/4981)
# Obtaining fair value for NOC (199/4981)
# Obtaining fair value for 373220.KS (200/4981)
# Failed to obtain fair value for 373220.KS
# list index out of range
# Obtaining fair value for FCX (201/4981)
# Obtaining fair value for SEMHF (202/4981)
# Obtaining fair value for IBDSF (203/4981)
# Obtaining fair value for EOG (204/4981)
# Obtaining fair value for CNQ (205/4981)
# Obtaining fair value for ZURN.SW (206/4981)
# Failed to obtain fair value for ZURN.SW
# list index out of range
# Obtaining fair value for 601012.SS (207/4981)
# Failed to obtain fair value for 601012.SS
# list index out of range
# Obtaining fair value for RCRRF (208/4981)
# Obtaining fair value for LRCX (209/4981)
# Obtaining fair value for ENLAY (210/4981)
# Obtaining fair value for D (211/4981)
# Obtaining fair value for BNPQF (212/4981)
# Obtaining fair value for GD (213/4981)
# Obtaining fair value for AXAHY (214/4981)
# Obtaining fair value for ITW (215/4981)
# Obtaining fair value for 002415.SZ (216/4981)
# Failed to obtain fair value for 002415.SZ
# list index out of range
# Obtaining fair value for SFTBF (217/4981)
# Obtaining fair value for WM (218/4981)
# Obtaining fair value for NSC (219/4981)
# Obtaining fair value for EW (220/4981)
# Obtaining fair value for F (221/4981)
# Obtaining fair value for AON (222/4981)
# Obtaining fair value for 601166.SS (223/4981)
# Failed to obtain fair value for 601166.SS
# list index out of range
# Obtaining fair value for WMMVF (224/4981)
# Obtaining fair value for IBN (225/4981)
# Obtaining fair value for PSA (226/4981)
# Obtaining fair value for ATLKY (227/4981)
# Obtaining fair value for DBSDF (228/4981)
# Obtaining fair value for OLL.F (229/4981)
# Failed to obtain fair value for OLL.F
# list index out of range
# Obtaining fair value for DP4A.F (230/4981)
# Failed to obtain fair value for DP4A.F
# list index out of range
# Obtaining fair value for HINDUNILVR.NS (231/4981)
# Failed to obtain fair value for HINDUNILVR.NS
# list index out of range
# Obtaining fair value for 000333.SZ (232/4981)
# Failed to obtain fair value for 000333.SZ
# list index out of range
# Obtaining fair value for 000660.KS (233/4981)
# Failed to obtain fair value for 000660.KS
# list index out of range
# Obtaining fair value for EQIX (234/4981)
# Obtaining fair value for CL (235/4981)
# Obtaining fair value for CFR.SW (236/4981)
# Failed to obtain fair value for CFR.SW
# list index out of range
# Obtaining fair value for SHW (237/4981)
# Obtaining fair value for PGR (238/4981)
# Obtaining fair value for SHECF (239/4981)
# Obtaining fair value for VRTX (240/4981)
# Obtaining fair value for TEAM (241/4981)
# Obtaining fair value for MRNA (242/4981)
# Obtaining fair value for BAYZF (243/4981)
# Obtaining fair value for NEM (244/4981)
# Obtaining fair value for SLB (245/4981)
# Obtaining fair value for UBER (246/4981)
# Obtaining fair value for 603288.SS (247/4981)
# Failed to obtain fair value for 603288.SS
# list index out of range
# Obtaining fair value for DASTF (248/4981)
# Obtaining fair value for BSX (249/4981)
# Obtaining fair value for AMX (250/4981)
# Obtaining fair value for GM (251/4981)
# Obtaining fair value for SQ (252/4981)
# Obtaining fair value for ETN (253/4981)
# Obtaining fair value for UBS (254/4981)
# Obtaining fair value for 7010.SR (255/4981)
# Failed to obtain fair value for 7010.SR
# list index out of range
# Obtaining fair value for HKXCF (256/4981)
# Obtaining fair value for SBIN.NS (257/4981)
# Failed to obtain fair value for SBIN.NS
# list index out of range
# Obtaining fair value for WDAY (258/4981)
# Obtaining fair value for 300760.SZ (259/4981)
# Failed to obtain fair value for 300760.SZ
# list index out of range
# Obtaining fair value for MCO (260/4981)
# Obtaining fair value for CM (261/4981)
# Obtaining fair value for FDX (262/4981)
# Obtaining fair value for SNOW (263/4981)
# Obtaining fair value for SAN (264/4981)
# Obtaining fair value for COF (265/4981)
# Obtaining fair value for DG.PA (266/4981)
# Failed to obtain fair value for DG.PA
# list index out of range
# Obtaining fair value for EMR (267/4981)
# Obtaining fair value for BFFAF (268/4981)
# Obtaining fair value for HUM (269/4981)
# Obtaining fair value for LS4C.F (270/4981)
# Failed to obtain fair value for LS4C.F
# list index out of range
# Obtaining fair value for NTR (271/4981)
# Obtaining fair value for NGG (272/4981)
# Obtaining fair value for FIS (273/4981)
# Obtaining fair value for ANZ.AX (274/4981)
# Failed to obtain fair value for ANZ.AX
# list index out of range
# Obtaining fair value for DOGEF (275/4981)
# Obtaining fair value for RELX (276/4981)
# Obtaining fair value for PANW (277/4981)
# Obtaining fair value for RBGPF (278/4981)
# Obtaining fair value for SCCO (279/4981)
# Obtaining fair value for ADYYF (280/4981)
# Obtaining fair value for HLAG.DE (281/4981)
# Failed to obtain fair value for HLAG.DE
# list index out of range
# Obtaining fair value for BHARTIARTL.NS (282/4981)
# Failed to obtain fair value for BHARTIARTL.NS
# list index out of range
# Obtaining fair value for MET (283/4981)
# Obtaining fair value for EPD (284/4981)
# Obtaining fair value for MAR (285/4981)
# Obtaining fair value for KDP (286/4981)
# Obtaining fair value for BKFCF (287/4981)
# Obtaining fair value for TRP (288/4981)
# Obtaining fair value for HEIA.AS (289/4981)
# Failed to obtain fair value for HEIA.AS
# list index out of range
# Obtaining fair value for BAJFINANCE.NS (290/4981)
# Failed to obtain fair value for BAJFINANCE.NS
# list index out of range
# Obtaining fair value for DKILY (291/4981)
# Obtaining fair value for OXY (292/4981)
# Obtaining fair value for FRCOF (293/4981)
# Obtaining fair value for MQG.AX (294/4981)
# Failed to obtain fair value for MQG.AX
# list index out of range
# Obtaining fair value for BMW.DE (295/4981)
# Failed to obtain fair value for BMW.DE
# list index out of range
# Obtaining fair value for OEWA.F (296/4981)
# Failed to obtain fair value for OEWA.F
# list index out of range
# Obtaining fair value for 2454.TW (297/4981)
# Failed to obtain fair value for 2454.TW
# list index out of range
# Obtaining fair value for SE (298/4981)
# Obtaining fair value for 0883.HK (299/4981)
# Failed to obtain fair value for 0883.HK
# list index out of range
# Obtaining fair value for E (300/4981)
# Obtaining fair value for MRVL (301/4981)
# Obtaining fair value for 0728.HK (302/4981)
# Failed to obtain fair value for 0728.HK
# list index out of range
# Obtaining fair value for TRI (303/4981)
# Obtaining fair value for RI.PA (304/4981)
# Failed to obtain fair value for RI.PA
# list index out of range
# Obtaining fair value for NTES (305/4981)
# Obtaining fair value for ITOCF (306/4981)
# Obtaining fair value for LONN.SW (307/4981)
# Failed to obtain fair value for LONN.SW
# list index out of range
# Obtaining fair value for 9633.HK (308/4981)
# Failed to obtain fair value for 9633.HK
# list index out of range
# Obtaining fair value for CNC (309/4981)
# Obtaining fair value for 601888.SS (310/4981)
# Failed to obtain fair value for 601888.SS
# list index out of range
# Obtaining fair value for 2317.TW (311/4981)
# Failed to obtain fair value for 2317.TW
# list index out of range
# Obtaining fair value for BSBR (312/4981)
# Obtaining fair value for SNAP (313/4981)
# Obtaining fair value for DG (314/4981)
# Obtaining fair value for BYRA.F (315/4981)
# Failed to obtain fair value for BYRA.F
# list index out of range
# Obtaining fair value for SRE (316/4981)
# Obtaining fair value for APD (317/4981)
# Obtaining fair value for BCE (318/4981)
# Obtaining fair value for LHX (319/4981)
# Obtaining fair value for KLAC (320/4981)
# Obtaining fair value for ILMN (321/4981)
# Obtaining fair value for SPG (322/4981)
# Obtaining fair value for SAFRF (323/4981)
# Obtaining fair value for STLA (324/4981)
# Obtaining fair value for ITUB (325/4981)
# Obtaining fair value for AEP (326/4981)
# Obtaining fair value for ECL (327/4981)
# Obtaining fair value for AIG (328/4981)
# Obtaining fair value for ROP (329/4981)
# Obtaining fair value for ADM (330/4981)
# Obtaining fair value for KHC (331/4981)
# Obtaining fair value for SMFG (332/4981)
# Obtaining fair value for CTSH (333/4981)
# Obtaining fair value for HMC (334/4981)
# Obtaining fair value for TAK (335/4981)
# Obtaining fair value for NXPI (336/4981)
# Obtaining fair value for DNZOF (337/4981)
# Obtaining fair value for ORLY (338/4981)
# Obtaining fair value for MELI (339/4981)
# Obtaining fair value for DOW (340/4981)
# Obtaining fair value for KOTAKBANK.NS (341/4981)
# Failed to obtain fair value for KOTAKBANK.NS
# list index out of range
# Obtaining fair value for JARLF (342/4981)
# Obtaining fair value for FTNT (343/4981)
# Obtaining fair value for NNDNF (344/4981)
# Obtaining fair value for XIACF (345/4981)
# Obtaining fair value for SIKA.SW (346/4981)
# Failed to obtain fair value for SIKA.SW
# list index out of range
# Obtaining fair value for SU (347/4981)
# Obtaining fair value for LYG (348/4981)
# Obtaining fair value for 207940.KS (349/4981)
# Failed to obtain fair value for 207940.KS
# list index out of range
# Obtaining fair value for KKR (350/4981)
# Obtaining fair value for MPC (351/4981)
# Obtaining fair value for HTHIF (352/4981)
# Obtaining fair value for PAYX (353/4981)
# Obtaining fair value for BIDU (354/4981)
# Obtaining fair value for 600030.SS (355/4981)
# Failed to obtain fair value for 600030.SS
# list index out of range
# Obtaining fair value for VOD (356/4981)
# Obtaining fair value for APH (357/4981)
# Obtaining fair value for 000001.SZ (358/4981)
# Failed to obtain fair value for 000001.SZ
# list index out of range
# Obtaining fair value for TRV (359/4981)
# Obtaining fair value for SNPS (360/4981)
# Obtaining fair value for MCK (361/4981)
# Obtaining fair value for EXC (362/4981)
# Obtaining fair value for ADDDF (363/4981)
# Obtaining fair value for JCI (364/4981)
# Obtaining fair value for ISNPY (365/4981)
# Obtaining fair value for HSY (366/4981)
# Obtaining fair value for GMBXF (367/4981)
# Obtaining fair value for ABEV (368/4981)
# Obtaining fair value for GOLD (369/4981)
# Obtaining fair value for WIT (370/4981)
# Obtaining fair value for CRWD (371/4981)
# Obtaining fair value for STZ (372/4981)
# Obtaining fair value for 300059.SZ (373/4981)
# Failed to obtain fair value for 300059.SZ
# list index out of range
# Obtaining fair value for ADSK (374/4981)
# Obtaining fair value for HCLTECH.NS (375/4981)
# Failed to obtain fair value for HCLTECH.NS
# list index out of range
# Obtaining fair value for MLYBY (376/4981)
# Obtaining fair value for CMG (377/4981)
# Obtaining fair value for TEL (378/4981)
# Obtaining fair value for WBA (379/4981)
# Obtaining fair value for DSV.VI (380/4981)
# Failed to obtain fair value for DSV.VI
# list index out of range
# Obtaining fair value for PRU (381/4981)
# Obtaining fair value for KMI (382/4981)
# Obtaining fair value for IDXX (383/4981)
# Obtaining fair value for WES.AX (384/4981)
# Failed to obtain fair value for WES.AX
# list index out of range
# Obtaining fair value for NDA-FI.HE (385/4981)
# Failed to obtain fair value for NDA-FI.HE
# list index out of range
# Obtaining fair value for SVNDF (386/4981)
# Obtaining fair value for BK (387/4981)
# Obtaining fair value for 8031.T (388/4981)
# Failed to obtain fair value for 8031.T
# list index out of range
# Obtaining fair value for 002714.SZ (389/4981)
# Failed to obtain fair value for 002714.SZ
# list index out of range
# Obtaining fair value for RSG (390/4981)
# Obtaining fair value for WELL (391/4981)
# Obtaining fair value for IQV (392/4981)
# Obtaining fair value for PDD (393/4981)
# Obtaining fair value for 601899.SS (394/4981)
# Failed to obtain fair value for 601899.SS
# list index out of range
# Obtaining fair value for COIN (395/4981)
# Obtaining fair value for KR (396/4981)
# Obtaining fair value for KMB (397/4981)
# Obtaining fair value for MRAAF (398/4981)
# Obtaining fair value for DELL (399/4981)
# Obtaining fair value for DXCM (400/4981)
# Obtaining fair value for HLT (401/4981)
# Obtaining fair value for CTVA (402/4981)
# Obtaining fair value for 035420.KS (403/4981)
# Failed to obtain fair value for 035420.KS
# list index out of range
# Obtaining fair value for AFL (404/4981)
# Obtaining fair value for 002475.SZ (405/4981)
# Failed to obtain fair value for 002475.SZ
# list index out of range
# Obtaining fair value for BAX (406/4981)
# Obtaining fair value for PUK (407/4981)
# Obtaining fair value for BBD (408/4981)
# Obtaining fair value for SYY (409/4981)
# Obtaining fair value for VNA.DE (410/4981)
# Failed to obtain fair value for VNA.DE
# list index out of range
# Obtaining fair value for CTAS (411/4981)
# Obtaining fair value for HYB.F (412/4981)
# Failed to obtain fair value for HYB.F
# list index out of range
# Obtaining fair value for 1211.SR (413/4981)
# Failed to obtain fair value for 1211.SR
# list index out of range
# Obtaining fair value for CMPGF (414/4981)
# Obtaining fair value for CDNS (415/4981)
# Obtaining fair value for DLR (416/4981)
# Obtaining fair value for MFC (417/4981)
# Obtaining fair value for 600309.SS (418/4981)
# Failed to obtain fair value for 600309.SS
# list index out of range
# Obtaining fair value for IFX.DE (419/4981)
# Failed to obtain fair value for IFX.DE
# list index out of range
# Obtaining fair value for O39.SI (420/4981)
# Failed to obtain fair value for O39.SI
# list index out of range
# Obtaining fair value for O (421/4981)
# Obtaining fair value for A (422/4981)
# Obtaining fair value for ITC.NS (423/4981)
# Failed to obtain fair value for ITC.NS
# list index out of range
# Obtaining fair value for MH6.F (424/4981)
# Failed to obtain fair value for MH6.F
# list index out of range
# Obtaining fair value for FMG.AX (425/4981)
# Failed to obtain fair value for FMG.AX
# list index out of range
# Obtaining fair value for BKR (426/4981)
# Obtaining fair value for MCHP (427/4981)
# Obtaining fair value for LULU (428/4981)
# Obtaining fair value for XEL (429/4981)
# Obtaining fair value for WMB (430/4981)
# Obtaining fair value for GIS (431/4981)
# Obtaining fair value for U11.SI (432/4981)
# Failed to obtain fair value for U11.SI
# list index out of range
# Obtaining fair value for AZO (433/4981)
# Obtaining fair value for DDOG (434/4981)
# Obtaining fair value for ADANIGREEN.NS (435/4981)
# Failed to obtain fair value for ADANIGREEN.NS
# list index out of range
# Obtaining fair value for ASIANPAINT.NS (436/4981)
# Failed to obtain fair value for ASIANPAINT.NS
# list index out of range
# Obtaining fair value for MSCI (437/4981)
# Obtaining fair value for DD (438/4981)
# Obtaining fair value for 2359.HK (439/4981)
# Failed to obtain fair value for 2359.HK
# list index out of range
# Obtaining fair value for BCS (440/4981)
# Obtaining fair value for VLO (441/4981)
# Obtaining fair value for 2388.HK (442/4981)
# Failed to obtain fair value for 2388.HK
# list index out of range
# Obtaining fair value for 002352.SZ (443/4981)
# Failed to obtain fair value for 002352.SZ
# list index out of range
# Obtaining fair value for BNTX (444/4981)
# Obtaining fair value for ING (445/4981)
# Obtaining fair value for MSI (446/4981)
# Obtaining fair value for BN.PA (447/4981)
# Failed to obtain fair value for BN.PA
# list index out of range
# Obtaining fair value for CARR (448/4981)
# Obtaining fair value for BBVA (449/4981)
# Obtaining fair value for VOLVF (450/4981)
# Obtaining fair value for 600276.SS (451/4981)
# Failed to obtain fair value for 600276.SS
# list index out of range
# Obtaining fair value for ALC (452/4981)
# Obtaining fair value for 035720.KS (453/4981)
# Failed to obtain fair value for 035720.KS
# list index out of range
# Obtaining fair value for DMART.NS (454/4981)
# Failed to obtain fair value for DMART.NS
# list index out of range
# Obtaining fair value for GPN (455/4981)
# Obtaining fair value for HPQ (456/4981)
# Obtaining fair value for APO (457/4981)
# Obtaining fair value for GIVN.SW (458/4981)
# Failed to obtain fair value for GIVN.SW
# list index out of range
# Obtaining fair value for 600000.SS (459/4981)
# Failed to obtain fair value for 600000.SS
# list index out of range
# Obtaining fair value for SMECF (460/4981)
# Obtaining fair value for LCID (461/4981)
# Obtaining fair value for RACE (462/4981)
# Obtaining fair value for ANET (463/4981)
# Obtaining fair value for 600887.SS (464/4981)
# Failed to obtain fair value for 600887.SS
# list index out of range
# Obtaining fair value for 601919.SS (465/4981)
# Failed to obtain fair value for 601919.SS
# list index out of range
# Obtaining fair value for NUE (466/4981)
# Obtaining fair value for STM (467/4981)
# Obtaining fair value for HXGBF (468/4981)
# Obtaining fair value for CRARF (469/4981)
# Obtaining fair value for TT (470/4981)
# Obtaining fair value for PH (471/4981)
# Obtaining fair value for DSKYF (472/4981)
# Obtaining fair value for ALL (473/4981)
# Obtaining fair value for 002142.SZ (474/4981)
# Failed to obtain fair value for 002142.SZ
# list index out of range
# Obtaining fair value for DVN (475/4981)
# Obtaining fair value for TU (476/4981)
# Obtaining fair value for 0011.HK (477/4981)
# Failed to obtain fair value for 0011.HK
# list index out of range
# Obtaining fair value for EC (478/4981)
# Obtaining fair value for WCN (479/4981)
# Obtaining fair value for SBAC (480/4981)
# Obtaining fair value for RMD (481/4981)
# Obtaining fair value for EXPGF (482/4981)
# Obtaining fair value for TDG (483/4981)
# Obtaining fair value for PSX (484/4981)
# Obtaining fair value for ODFL (485/4981)
# Obtaining fair value for CAPMF (486/4981)
# Obtaining fair value for DLTR (487/4981)
# Obtaining fair value for LYB (488/4981)
# Obtaining fair value for 1876.HK (489/4981)
# Failed to obtain fair value for 1876.HK
# list index out of range
# Obtaining fair value for CSU.TO (490/4981)
# Failed to obtain fair value for CSU.TO
# list index out of range
# Obtaining fair value for MFG (491/4981)
# Obtaining fair value for FERG (492/4981)
# Obtaining fair value for 5110.SR (493/4981)
# Failed to obtain fair value for 5110.SR
# list index out of range
# Obtaining fair value for EQR (494/4981)
# Obtaining fair value for CHT (495/4981)
# Obtaining fair value for EA (496/4981)
# Obtaining fair value for KNIN.SW (497/4981)
# Failed to obtain fair value for KNIN.SW
# list index out of range
# Obtaining fair value for AVB (498/4981)
# Obtaining fair value for PTT-R.BK (499/4981)
# Failed to obtain fair value for PTT-R.BK
# list index out of range
# Obtaining fair value for DNB.OL (500/4981)
# Failed to obtain fair value for DNB.OL
# list index out of range
# Obtaining fair value for PEG (501/4981)
# Obtaining fair value for YUM (502/4981)
# Obtaining fair value for TLS.AX (503/4981)
# Failed to obtain fair value for TLS.AX
# list index out of range
# Obtaining fair value for LNG (504/4981)
# Obtaining fair value for 7182.T (505/4981)
# Failed to obtain fair value for 7182.T
# list index out of range
# Obtaining fair value for CRH (506/4981)
# Obtaining fair value for MPLX (507/4981)
# Obtaining fair value for HAL (508/4981)
# Obtaining fair value for 601633.SS (509/4981)
# Failed to obtain fair value for 601633.SS
# list index out of range
# Obtaining fair value for 0016.HK (510/4981)
# Failed to obtain fair value for 0016.HK
# list index out of range
# Obtaining fair value for BAJAJFINSV.NS (511/4981)
# Failed to obtain fair value for BAJAJFINSV.NS
# list index out of range
# Obtaining fair value for HYMTF (512/4981)
# Obtaining fair value for AJG (513/4981)
# Obtaining fair value for 4689.T (514/4981)
# Failed to obtain fair value for 4689.T
# list index out of range
# Obtaining fair value for 002304.SZ (515/4981)
# Failed to obtain fair value for 002304.SZ
# list index out of range
# Obtaining fair value for LT.NS (516/4981)
# Failed to obtain fair value for LT.NS
# list index out of range
# Obtaining fair value for 0066.HK (517/4981)
# Failed to obtain fair value for 0066.HK
# list index out of range
# Obtaining fair value for NWG (518/4981)
# Obtaining fair value for RIVN (519/4981)
# Obtaining fair value for TLK (520/4981)
# Obtaining fair value for ED (521/4981)
# Obtaining fair value for CODGF (522/4981)
# Obtaining fair value for 600104.SS (523/4981)
# Failed to obtain fair value for 600104.SS
# list index out of range
# Obtaining fair value for 6505.TW (524/4981)
# Failed to obtain fair value for 6505.TW
# list index out of range
# Obtaining fair value for FITB (525/4981)
# Obtaining fair value for FAST (526/4981)
# Obtaining fair value for NIO (527/4981)
# Obtaining fair value for GFS (528/4981)
# Obtaining fair value for TROW (529/4981)
# Obtaining fair value for WOW.AX (530/4981)
# Failed to obtain fair value for WOW.AX
# list index out of range
# Obtaining fair value for SLF (531/4981)
# Obtaining fair value for ORAN (532/4981)
# Obtaining fair value for SNGNF (533/4981)
# Obtaining fair value for DFS (534/4981)
# Obtaining fair value for OTIS (535/4981)
# Obtaining fair value for TSN (536/4981)
# Obtaining fair value for EQT.ST (537/4981)
# Failed to obtain fair value for EQT.ST
# list index out of range
# Obtaining fair value for GLW (538/4981)
# Obtaining fair value for DBOEF (539/4981)
# Obtaining fair value for EBAY (540/4981)
# Obtaining fair value for JAPAF (541/4981)
# Obtaining fair value for CLNX.MC (542/4981)
# Failed to obtain fair value for CLNX.MC
# list index out of range
# Obtaining fair value for 601601.SS (543/4981)
# Failed to obtain fair value for 601601.SS
# list index out of range
# Obtaining fair value for AHCHF (544/4981)
# Obtaining fair value for STT (545/4981)
# Obtaining fair value for 601138.SS (546/4981)
# Failed to obtain fair value for 601138.SS
# list index out of range
# Obtaining fair value for PGHN.SW (547/4981)
# Failed to obtain fair value for PGHN.SW
# list index out of range
# Obtaining fair value for SCMN.SW (548/4981)
# Failed to obtain fair value for SCMN.SW
# list index out of range
# Obtaining fair value for NU (549/4981)
# Obtaining fair value for AHODF (550/4981)
# Obtaining fair value for AMP (551/4981)
# Obtaining fair value for ROST (552/4981)
# Obtaining fair value for G.MI (553/4981)
# Failed to obtain fair value for G.MI
# list index out of range
# Obtaining fair value for PCAR (554/4981)
# Obtaining fair value for 1024.HK (555/4981)
# Failed to obtain fair value for 1024.HK
# list index out of range
# Obtaining fair value for HELKF (556/4981)
# Obtaining fair value for FNV (557/4981)
# Obtaining fair value for ET (558/4981)
# Obtaining fair value for EOAN.DE (559/4981)
# Failed to obtain fair value for EOAN.DE
# list index out of range
# Obtaining fair value for ARE (560/4981)
# Obtaining fair value for UDR (561/4981)
# Obtaining fair value for 2881.TW (562/4981)
# Failed to obtain fair value for 2881.TW
# list index out of range
# Obtaining fair value for VRSK (563/4981)
# Obtaining fair value for L.TO (564/4981)
# Failed to obtain fair value for L.TO
# list index out of range
# Obtaining fair value for CVE (565/4981)
# Obtaining fair value for AS7.F (566/4981)
# Failed to obtain fair value for AS7.F
# list index out of range
# Obtaining fair value for ALGN (567/4981)
# Obtaining fair value for NESTE.HE (568/4981)
# Failed to obtain fair value for NESTE.HE
# list index out of range
# Obtaining fair value for ENGI.PA (569/4981)
# Failed to obtain fair value for ENGI.PA
# list index out of range
# Obtaining fair value for ROK (570/4981)
# Obtaining fair value for GMG.AX (571/4981)
# Failed to obtain fair value for GMG.AX
# list index out of range
# Obtaining fair value for 0LC.F (572/4981)
# Failed to obtain fair value for 0LC.F
# list index out of range
# Obtaining fair value for 000651.SZ (573/4981)
# Failed to obtain fair value for 000651.SZ
# list index out of range
# Obtaining fair value for KBCSF (574/4981)
# Obtaining fair value for TITAN.NS (575/4981)
# Failed to obtain fair value for TITAN.NS
# list index out of range
# Obtaining fair value for IFF (576/4981)
# Obtaining fair value for KDSKF (577/4981)
# Obtaining fair value for AME (578/4981)
# Obtaining fair value for WEC (579/4981)
# Obtaining fair value for 1010.SR (580/4981)
# Failed to obtain fair value for 1010.SR
# list index out of range
# Obtaining fair value for MTD (581/4981)
# Obtaining fair value for BSP.F (582/4981)
# Failed to obtain fair value for BSP.F
# list index out of range
# Obtaining fair value for ZM (583/4981)
# Obtaining fair value for 2603.TW (584/4981)
# Failed to obtain fair value for 2603.TW
# list index out of range
# Obtaining fair value for BF-A (585/4981)
# Failed to obtain fair value for BF-A
# list index out of range
# Obtaining fair value for 6178.T (586/4981)
# Failed to obtain fair value for 6178.T
# list index out of range
# Obtaining fair value for NOK (587/4981)
# Obtaining fair value for MARUTI.NS (588/4981)
# Failed to obtain fair value for MARUTI.NS
# list index out of range
# Obtaining fair value for HES (589/4981)
# Obtaining fair value for TIB1.F (590/4981)
# Failed to obtain fair value for TIB1.F
# list index out of range
# Obtaining fair value for CBRE (591/4981)
# Obtaining fair value for WY (592/4981)
# Obtaining fair value for IMO (593/4981)
# Obtaining fair value for PPG (594/4981)
# Obtaining fair value for NET (595/4981)
# Obtaining fair value for ERIC (596/4981)
# Obtaining fair value for OKE (597/4981)
# Obtaining fair value for BIIB (598/4981)
# Obtaining fair value for TCL.AX (599/4981)
# Failed to obtain fair value for TCL.AX
# list index out of range
# Obtaining fair value for ES (600/4981)
# Obtaining fair value for ZS (601/4981)
# Obtaining fair value for WXXWY (602/4981)
# Obtaining fair value for CPNG (603/4981)
# Obtaining fair value for FJTSY (604/4981)
# Obtaining fair value for 2882.TW (605/4981)
# Failed to obtain fair value for 2882.TW
# list index out of range
# Obtaining fair value for APTV (606/4981)
# Obtaining fair value for SUNPHARMA.NS (607/4981)
# Failed to obtain fair value for SUNPHARMA.NS
# list index out of range
# Obtaining fair value for CMI (608/4981)
# Obtaining fair value for CBHD.F (609/4981)
# Failed to obtain fair value for CBHD.F
# list index out of range
# Obtaining fair value for EXPE (610/4981)
# Obtaining fair value for EFX (611/4981)
# Obtaining fair value for AXISBANK.BO (612/4981)
# Failed to obtain fair value for AXISBANK.BO
# list index out of range
# Obtaining fair value for KNEBV.HE (613/4981)
# Failed to obtain fair value for KNEBV.HE
# list index out of range
# Obtaining fair value for MT (614/4981)
# Obtaining fair value for TW (615/4981)
# Obtaining fair value for AWK (616/4981)
# Obtaining fair value for ASAZF (617/4981)
# Obtaining fair value for CPRT (618/4981)
# Obtaining fair value for PHG (619/4981)
# Obtaining fair value for DHI (620/4981)
# Obtaining fair value for WST (621/4981)
# Obtaining fair value for NDAQ (622/4981)
# Obtaining fair value for AMADF (623/4981)
# Obtaining fair value for 0688.HK (624/4981)
# Failed to obtain fair value for 0688.HK
# list index out of range
# Obtaining fair value for AEM (625/4981)
# Obtaining fair value for HRL (626/4981)
# Obtaining fair value for FSRA.F (627/4981)
# Failed to obtain fair value for FSRA.F
# list index out of range
# Obtaining fair value for TSCDF (628/4981)
# Obtaining fair value for AOT.BK (629/4981)
# Failed to obtain fair value for AOT.BK
# list index out of range
# Obtaining fair value for EXR (630/4981)
# Obtaining fair value for RCI (631/4981)
# Obtaining fair value for SAND.ST (632/4981)
# Failed to obtain fair value for SAND.ST
# list index out of range
# Obtaining fair value for RWE.DE (633/4981)
# Failed to obtain fair value for RWE.DE
# list index out of range
# Obtaining fair value for 9022.T (634/4981)
# Failed to obtain fair value for 9022.T
# list index out of range
# Obtaining fair value for DASH (635/4981)
# Obtaining fair value for ONGC.NS (636/4981)
# Failed to obtain fair value for ONGC.NS
# list index out of range
# Obtaining fair value for 0003.HK (637/4981)
# Failed to obtain fair value for 0003.HK
# list index out of range
# Obtaining fair value for GWO.TO (638/4981)
# Failed to obtain fair value for GWO.TO
# list index out of range
# Obtaining fair value for CABK.MC (639/4981)
# Failed to obtain fair value for CABK.MC
# list index out of range
# Obtaining fair value for VEEV (640/4981)
# Obtaining fair value for MKC (641/4981)
# Obtaining fair value for 051910.KS (642/4981)
# Failed to obtain fair value for 051910.KS
# list index out of range
# Obtaining fair value for KEYS (643/4981)
# Obtaining fair value for NA.TO (644/4981)
# Failed to obtain fair value for NA.TO
# list index out of range
# Obtaining fair value for 9613.T (645/4981)
# Failed to obtain fair value for 9613.T
# list index out of range
# Obtaining fair value for WTW (646/4981)
# Obtaining fair value for 1339.HK (647/4981)
# Failed to obtain fair value for 1339.HK
# list index out of range
# Obtaining fair value for 5108.T (648/4981)
# Failed to obtain fair value for 5108.T
# list index out of range
# Obtaining fair value for PPERF (649/4981)
# Obtaining fair value for LISN.SW (650/4981)
# Failed to obtain fair value for LISN.SW
# list index out of range
# Obtaining fair value for IBKR (651/4981)
# Obtaining fair value for 0001.HK (652/4981)
# Failed to obtain fair value for 0001.HK
# list index out of range
# Obtaining fair value for WOSB.F (653/4981)
# Failed to obtain fair value for WOSB.F
# list index out of range
# Obtaining fair value for WEGE3.SA (654/4981)
# Failed to obtain fair value for WEGE3.SA
# list index out of range
# Obtaining fair value for SRT.DE (655/4981)
# Failed to obtain fair value for SRT.DE
# list index out of range
# Obtaining fair value for SREN.SW (656/4981)
# Failed to obtain fair value for SREN.SW
# list index out of range
# Obtaining fair value for HO.PA (657/4981)
# Failed to obtain fair value for HO.PA
# list index out of range
# Obtaining fair value for RPRX (658/4981)
# Obtaining fair value for QSR (659/4981)
# Obtaining fair value for BEP (660/4981)
# Obtaining fair value for NTGY.MC (661/4981)
# Failed to obtain fair value for NTGY.MC
# list index out of range
# Obtaining fair value for TTD (662/4981)
# Obtaining fair value for TSCO (663/4981)
# Obtaining fair value for ANSS (664/4981)
# Obtaining fair value for IFC.TO (665/4981)
# Failed to obtain fair value for IFC.TO
# list index out of range
# Obtaining fair value for 1303.TW (666/4981)
# Failed to obtain fair value for 1303.TW
# list index out of range
# Obtaining fair value for TEF (667/4981)
# Obtaining fair value for 2020.SR (668/4981)
# Failed to obtain fair value for 2020.SR
# list index out of range
# Obtaining fair value for MTCH (669/4981)
# Obtaining fair value for FE (670/4981)
# Obtaining fair value for SAMPO.HE (671/4981)
# Failed to obtain fair value for SAMPO.HE
# list index out of range
# Obtaining fair value for EBK.DE (672/4981)
# Failed to obtain fair value for EBK.DE
# list index out of range
# Obtaining fair value for PCG (673/4981)
# Obtaining fair value for LRC.F (674/4981)
# Failed to obtain fair value for LRC.F
# list index out of range
# Obtaining fair value for 000725.SZ (675/4981)
# Failed to obtain fair value for 000725.SZ
# list index out of range
# Obtaining fair value for 0002.HK (676/4981)
# Failed to obtain fair value for 0002.HK
# list index out of range
# Obtaining fair value for BPAC3.SA (677/4981)
# Failed to obtain fair value for BPAC3.SA
# list index out of range
# Obtaining fair value for LH (678/4981)
# Obtaining fair value for GWW (679/4981)
# Obtaining fair value for 300015.SZ (680/4981)
# Failed to obtain fair value for 300015.SZ
# list index out of range
# Obtaining fair value for ZBH (681/4981)
# Obtaining fair value for 601818.SS (682/4981)
# Failed to obtain fair value for 601818.SS
# list index out of range
# Obtaining fair value for EIX (683/4981)
# Obtaining fair value for LVS (684/4981)
# Obtaining fair value for DB (685/4981)
# Obtaining fair value for HMRZF (686/4981)
# Obtaining fair value for MAA (687/4981)
# Obtaining fair value for 2202.HK (688/4981)
# Failed to obtain fair value for 2202.HK
# list index out of range
# Obtaining fair value for DTE (689/4981)
# Obtaining fair value for LYV (690/4981)
# Obtaining fair value for ADANIENT.NS (691/4981)
# Failed to obtain fair value for ADANIENT.NS
# list index out of range
# Obtaining fair value for SIRI (692/4981)
# Obtaining fair value for INVH (693/4981)
# Obtaining fair value for BT-A.L (694/4981)
# Failed to obtain fair value for BT-A.L
# list index out of range
# Obtaining fair value for MKN2.F (695/4981)
# Failed to obtain fair value for MKN2.F
# list index out of range
# Obtaining fair value for 601066.SS (696/4981)
# Failed to obtain fair value for 601066.SS
# list index out of range
# Obtaining fair value for LEN (697/4981)
# Obtaining fair value for SPOT (698/4981)
# Obtaining fair value for MIELF (699/4981)
# Obtaining fair value for 1301.TW (700/4981)
# Failed to obtain fair value for 1301.TW
# list index out of range
# Obtaining fair value for LUV (701/4981)
# Obtaining fair value for VMC (702/4981)
# Obtaining fair value for CHD (703/4981)
# Obtaining fair value for SWK (704/4981)
# Obtaining fair value for MLM (705/4981)
# Obtaining fair value for 4901.T (706/4981)
# Failed to obtain fair value for 4901.T
# list index out of range
# Obtaining fair value for ON (707/4981)
# Obtaining fair value for CQP (708/4981)
# Obtaining fair value for RBLX (709/4981)
# Obtaining fair value for URI (710/4981)
# Obtaining fair value for VTR (711/4981)
# Obtaining fair value for SEBA.F (712/4981)
# Failed to obtain fair value for SEBA.F
# list index out of range
# Obtaining fair value for SCHN.SW (713/4981)
# Failed to obtain fair value for SCHN.SW
# list index out of range
# Obtaining fair value for FANG (714/4981)
# Obtaining fair value for SCT.F (715/4981)
# Failed to obtain fair value for SCT.F
# list index out of range
# Obtaining fair value for OKTA (716/4981)
# Obtaining fair value for 2308.TW (717/4981)
# Failed to obtain fair value for 2308.TW
# list index out of range
# Obtaining fair value for LBRDA (718/4981)
# Obtaining fair value for 1113.HK (719/4981)
# Failed to obtain fair value for 1113.HK
# list index out of range
# Obtaining fair value for 300124.SZ (720/4981)
# Failed to obtain fair value for 300124.SZ
# list index out of range
# Obtaining fair value for NTRS (721/4981)
# Obtaining fair value for 600016.SS (722/4981)
# Failed to obtain fair value for 600016.SS
# list index out of range
# Obtaining fair value for MOS (723/4981)
# Obtaining fair value for 4543.T (724/4981)
# Failed to obtain fair value for 4543.T
# list index out of range
# Obtaining fair value for TWLO (725/4981)
# Obtaining fair value for BBY (726/4981)
# Obtaining fair value for ULTRACEMCO.NS (727/4981)
# Failed to obtain fair value for ULTRACEMCO.NS
# list index out of range
# Obtaining fair value for 600031.SS (728/4981)
# Failed to obtain fair value for 600031.SS
# list index out of range
# Obtaining fair value for ESS (729/4981)
# Obtaining fair value for MTB (730/4981)
# Obtaining fair value for IT (731/4981)
# Obtaining fair value for CDW (732/4981)
# Obtaining fair value for EDRVF (733/4981)
# Obtaining fair value for IX (734/4981)
# Obtaining fair value for AEE (735/4981)
# Obtaining fair value for FTS (736/4981)
# Obtaining fair value for ML.PA (737/4981)
# Failed to obtain fair value for ML.PA
# list index out of range
# Obtaining fair value for ETR (738/4981)
# Obtaining fair value for HIG (739/4981)
# Obtaining fair value for SOON.SW (740/4981)
# Failed to obtain fair value for SOON.SW
# list index out of range
# Obtaining fair value for UMC (741/4981)
# Obtaining fair value for FRE.DE (742/4981)
# Failed to obtain fair value for FRE.DE
# list index out of range
# Obtaining fair value for 7733.T (743/4981)
# Failed to obtain fair value for 7733.T
# list index out of range
# Obtaining fair value for CSGP (744/4981)
# Obtaining fair value for AENA.MC (745/4981)
# Failed to obtain fair value for AENA.MC
# list index out of range
# Obtaining fair value for KEY (746/4981)
# Obtaining fair value for 6301.T (747/4981)
# Failed to obtain fair value for 6301.T
# list index out of range
# Obtaining fair value for UCG.MI (748/4981)
# Failed to obtain fair value for UCG.MI
# list index out of range
# Obtaining fair value for VRSN (749/4981)
# Obtaining fair value for LI (750/4981)
# Obtaining fair value for 6752.T (751/4981)
# Failed to obtain fair value for 6752.T
# list index out of range
# Obtaining fair value for STE (752/4981)
# Obtaining fair value for U (753/4981)
# Obtaining fair value for 9020.T (754/4981)
# Failed to obtain fair value for 9020.T
# list index out of range
# Obtaining fair value for DOV (755/4981)
# Obtaining fair value for NESTLEIND.NS (756/4981)
# Failed to obtain fair value for NESTLEIND.NS
# list index out of range
# Obtaining fair value for 8750.T (757/4981)
# Failed to obtain fair value for 8750.T
# list index out of range
# Obtaining fair value for AIVAF (758/4981)
# Obtaining fair value for NPSNY (759/4981)
# Obtaining fair value for 206G.F (760/4981)
# Failed to obtain fair value for 206G.F
# list index out of range
# Obtaining fair value for HBAN (761/4981)
# Obtaining fair value for HPE (762/4981)
# Obtaining fair value for TLPFF (763/4981)
# Obtaining fair value for EVO.ST (764/4981)
# Failed to obtain fair value for EVO.ST
# list index out of range
# Obtaining fair value for ELE.MC (765/4981)
# Failed to obtain fair value for ELE.MC
# list index out of range
# Obtaining fair value for STMN.SW (766/4981)
# Failed to obtain fair value for STMN.SW
# list index out of range
# Obtaining fair value for RLF.F (767/4981)
# Failed to obtain fair value for RLF.F
# list index out of range
# Obtaining fair value for MDB (768/4981)
# Obtaining fair value for PLTR (769/4981)
# Obtaining fair value for GMAB (770/4981)
# Obtaining fair value for WPM (771/4981)
# Obtaining fair value for CCEP (772/4981)
# Obtaining fair value for WLMIF (773/4981)
# Obtaining fair value for RF (774/4981)
# Obtaining fair value for VEOEF (775/4981)
# Obtaining fair value for GEBN.SW (776/4981)
# Failed to obtain fair value for GEBN.SW
# list index out of range
# Obtaining fair value for BEI.DE (777/4981)
# Failed to obtain fair value for BEI.DE
# list index out of range
# Obtaining fair value for 1060.SR (778/4981)
# Failed to obtain fair value for 1060.SR
# list index out of range
# Obtaining fair value for 6326.T (779/4981)
# Failed to obtain fair value for 6326.T
# list index out of range
# Obtaining fair value for ENPH (780/4981)
# Obtaining fair value for EPI-A.ST (781/4981)
# Failed to obtain fair value for EPI-A.ST
# list index out of range
# Obtaining fair value for 4307.T (782/4981)
# Failed to obtain fair value for 4307.T
# list index out of range
# Obtaining fair value for GRMN (783/4981)
# Obtaining fair value for FOX (784/4981)
# Obtaining fair value for ZTO (785/4981)
# Obtaining fair value for POW.TO (786/4981)
# Failed to obtain fair value for POW.TO
# list index out of range
# Obtaining fair value for 8113.T (787/4981)
# Failed to obtain fair value for 8113.T
# list index out of range
# Obtaining fair value for 8053.T (788/4981)
# Failed to obtain fair value for 8053.T
# list index out of range
# Obtaining fair value for VFC (789/4981)
# Obtaining fair value for UCB.VI (790/4981)
# Failed to obtain fair value for UCB.VI
# list index out of range
# Obtaining fair value for AVTR (791/4981)
# Obtaining fair value for ZI (792/4981)
# Obtaining fair value for 2002A.TW (793/4981)
# Failed to obtain fair value for 2002A.TW
# list index out of range
# Obtaining fair value for ALB (794/4981)
# Obtaining fair value for RKT (795/4981)
# Obtaining fair value for CFG (796/4981)
# Obtaining fair value for 2319.HK (797/4981)
# Failed to obtain fair value for 2319.HK
# list index out of range
# Obtaining fair value for CNHI (798/4981)
# Failed to obtain fair value for CNHI
# list index out of range
# Obtaining fair value for CINF (799/4981)
# ...
# Failed to obtain fair value for GEPIL.NS
# list index out of range
# Obtaining fair value for OFED (4683/4981)
# Obtaining fair value for EMKR (4684/4981)
# Obtaining fair value for LPCN (4685/4981)
# Obtaining fair value for KIRK (4686/4981)
# Obtaining fair value for ASUR (4687/4981)
# Obtaining fair value for PXLW (4688/4981)
# Obtaining fair value for TNPL.NS (4689/4981)
# Failed to obtain fair value for TNPL.NS
# list index out of range
# Obtaining fair value for 3903.T (4690/4981)
# Failed to obtain fair value for 3903.T
# list index out of range
# Obtaining fair value for ASXC (4691/4981)
# Obtaining fair value for MANGLMCEM.NS (4692/4981)
# Failed to obtain fair value for MANGLMCEM.NS
# list index out of range
# Obtaining fair value for LIFE (4693/4981)
# Obtaining fair value for INDNIPPON.NS (4694/4981)
# Failed to obtain fair value for INDNIPPON.NS
# list index out of range
# Obtaining fair value for ATER (4695/4981)
# Obtaining fair value for PLSE (4696/4981)
# Obtaining fair value for OPOF (4697/4981)
# Obtaining fair value for SND (4698/4981)
# Obtaining fair value for VADILALIND.NS (4699/4981)
# Failed to obtain fair value for VADILALIND.NS
# list index out of range
# Obtaining fair value for JAKK (4700/4981)
# Obtaining fair value for AGFY (4701/4981)
# Obtaining fair value for MTNB (4702/4981)
# Obtaining fair value for MDXH (4703/4981)
# Obtaining fair value for PARAGMILK.NS (4704/4981)
# Failed to obtain fair value for PARAGMILK.NS
# list index out of range
# Obtaining fair value for TXMD (4705/4981)
# Obtaining fair value for CTSO (4706/4981)
# Obtaining fair value for NCSM (4707/4981)
# Obtaining fair value for CLSD (4708/4981)
# Obtaining fair value for 3656.T (4709/4981)
# Failed to obtain fair value for 3656.T
# list index out of range
# Obtaining fair value for LGVN (4710/4981)
# Obtaining fair value for FBIO (4711/4981)
# Obtaining fair value for 3IINFOLTD.NS (4712/4981)
# Failed to obtain fair value for 3IINFOLTD.NS
# list index out of range
# Obtaining fair value for NNBR (4713/4981)
# Obtaining fair value for KALA (4714/4981)
# Obtaining fair value for RDI (4715/4981)
# Obtaining fair value for PORT.JK (4716/4981)
# Failed to obtain fair value for PORT.JK
# list index out of range
# Obtaining fair value for IVAC (4717/4981)
# Obtaining fair value for GP (4718/4981)
# Obtaining fair value for ADVM (4719/4981)
# Obtaining fair value for ARDX (4720/4981)
# Obtaining fair value for WHG (4721/4981)
# Obtaining fair value for PROV (4722/4981)
# Obtaining fair value for FI (4723/4981)
# Obtaining fair value for FTK (4724/4981)
# Obtaining fair value for SVRA (4725/4981)
# Obtaining fair value for OCX (4726/4981)
# Obtaining fair value for FLXS (4727/4981)
# Obtaining fair value for ITI (4728/4981)
# Obtaining fair value for PED (4729/4981)
# Obtaining fair value for AXDX (4730/4981)
# Obtaining fair value for FNGR (4731/4981)
# Obtaining fair value for SNCR (4732/4981)
# Obtaining fair value for LUMAXIND.NS (4733/4981)
# Failed to obtain fair value for LUMAXIND.NS
# list index out of range
# Obtaining fair value for APEX.NS (4734/4981)
# Failed to obtain fair value for APEX.NS
# list index out of range
# Obtaining fair value for FONR (4735/4981)
# Obtaining fair value for FARM (4736/4981)
# Obtaining fair value for PAVM (4737/4981)
# Obtaining fair value for BCLI (4738/4981)
# Obtaining fair value for RCOM.NS (4739/4981)
# Failed to obtain fair value for RCOM.NS
# list index out of range
# Obtaining fair value for SUP (4740/4981)
# Obtaining fair value for MNOV (4741/4981)
# Obtaining fair value for RANEHOLDIN.NS (4742/4981)
# Failed to obtain fair value for RANEHOLDIN.NS
# list index out of range
# Obtaining fair value for DARE (4743/4981)
# Obtaining fair value for MANGCHEFER.NS (4744/4981)
# Failed to obtain fair value for MANGCHEFER.NS
# list index out of range
# Obtaining fair value for LODE (4745/4981)
# Obtaining fair value for FOSECOIND.NS (4746/4981)
# Failed to obtain fair value for FOSECOIND.NS
# list index out of range
# Obtaining fair value for SLDB (4747/4981)
# Obtaining fair value for GAIA (4748/4981)
# Obtaining fair value for CAPACITE.NS (4749/4981)
# Failed to obtain fair value for CAPACITE.NS
# list index out of range
# Obtaining fair value for TUSK (4750/4981)
# Obtaining fair value for PAYS (4751/4981)
# Obtaining fair value for SMLP (4752/4981)
# Obtaining fair value for ACR (4753/4981)
# Obtaining fair value for RADIOCITY.NS (4754/4981)
# Failed to obtain fair value for RADIOCITY.NS
# list index out of range
# Obtaining fair value for VGZ (4755/4981)
# Obtaining fair value for LWAY (4756/4981)
# Obtaining fair value for AQB (4757/4981)
# Obtaining fair value for PWFL (4758/4981)
# Obtaining fair value for NINE (4759/4981)
# Obtaining fair value for TNXP (4760/4981)
# Obtaining fair value for HNRG (4761/4981)
# Obtaining fair value for GALT (4762/4981)
# Obtaining fair value for ANY (4763/4981)
# Obtaining fair value for BLISSGVS.NS (4764/4981)
# Failed to obtain fair value for BLISSGVS.NS
# list index out of range
# Obtaining fair value for ASRT (4765/4981)
# Obtaining fair value for 3793.T (4766/4981)
# Failed to obtain fair value for 3793.T
# list index out of range
# Obtaining fair value for 7060.T (4767/4981)
# Failed to obtain fair value for 7060.T
# list index out of range
# Obtaining fair value for AQST (4768/4981)
# Obtaining fair value for AUMN (4769/4981)
# Obtaining fair value for KUANTUM.NS (4770/4981)
# Failed to obtain fair value for KUANTUM.NS
# list index out of range
# Obtaining fair value for BALAJITELE.NS (4771/4981)
# Failed to obtain fair value for BALAJITELE.NS
# list index out of range
# Obtaining fair value for CMCM (4772/4981)
# Obtaining fair value for SCYX (4773/4981)
# Obtaining fair value for AMPE (4774/4981)
# Obtaining fair value for IFRX (4775/4981)
# Obtaining fair value for SPENCERS.NS (4776/4981)
# Failed to obtain fair value for SPENCERS.NS
# list index out of range
# Obtaining fair value for CBAT (4777/4981)
# Obtaining fair value for ASM (4778/4981)
# Obtaining fair value for SMLISUZU.NS (4779/4981)
# Failed to obtain fair value for SMLISUZU.NS
# list index out of range
# Obtaining fair value for CAPR (4780/4981)
# Obtaining fair value for SALM (4781/4981)
# Obtaining fair value for KLXE (4782/4981)
# Obtaining fair value for ATNF (4783/4981)
# Obtaining fair value for RDHL (4784/4981)
# Obtaining fair value for APTO (4785/4981)
# Obtaining fair value for SEEL (4786/4981)
# Obtaining fair value for YTRA (4787/4981)
# Obtaining fair value for SONX (4788/4981)
# Obtaining fair value for WTER (4789/4981)
# Obtaining fair value for DSS (4790/4981)
# Obtaining fair value for OESX (4791/4981)
# Obtaining fair value for HEPA (4792/4981)
# Obtaining fair value for ONCY (4793/4981)
# Obtaining fair value for ORIENTPPR.NS (4794/4981)
# Failed to obtain fair value for ORIENTPPR.NS
# list index out of range
# Obtaining fair value for PTN (4795/4981)
# Obtaining fair value for AUGX (4796/4981)
# Obtaining fair value for JAYBARMARU.NS (4797/4981)
# Failed to obtain fair value for JAYBARMARU.NS
# list index out of range
# Obtaining fair value for SKIPPER.NS (4798/4981)
# Failed to obtain fair value for SKIPPER.NS
# list index out of range
# Obtaining fair value for HYMC (4799/4981)
# Obtaining fair value for SLS (4800/4981)
# Obtaining fair value for NECLIFE.NS (4801/4981)
# Failed to obtain fair value for NECLIFE.NS
# list index out of range
# Obtaining fair value for IMTE (4802/4981)
# Obtaining fair value for GHM (4803/4981)
# Obtaining fair value for FAMI (4804/4981)
# Obtaining fair value for UNITECH.NS (4805/4981)
# Failed to obtain fair value for UNITECH.NS
# list index out of range
# Obtaining fair value for KOKUYOCMLN.NS (4806/4981)
# Failed to obtain fair value for KOKUYOCMLN.NS
# list index out of range
# Obtaining fair value for NHTC (4807/4981)
# Obtaining fair value for XNET (4808/4981)
# Obtaining fair value for WATT (4809/4981)
# Obtaining fair value for RGS (4810/4981)
# Obtaining fair value for ASIANTILES.NS (4811/4981)
# Failed to obtain fair value for ASIANTILES.NS
# list index out of range
# Obtaining fair value for VERB (4812/4981)
# Obtaining fair value for ANIX (4813/4981)
# Obtaining fair value for CDZI (4814/4981)
# Obtaining fair value for UAVS (4815/4981)
# Obtaining fair value for SSL.MI (4816/4981)
# Failed to obtain fair value for SSL.MI
# list index out of range
# Obtaining fair value for STERTOOLS.NS (4817/4981)
# Failed to obtain fair value for STERTOOLS.NS
# list index out of range
# Obtaining fair value for IBIO (4818/4981)
# Obtaining fair value for LUMO (4819/4981)
# Obtaining fair value for OPTT (4820/4981)
# Obtaining fair value for SOHO (4821/4981)
# Obtaining fair value for STAR-B.ST (4822/4981)
# Failed to obtain fair value for STAR-B.ST
# list index out of range
# Obtaining fair value for ORN (4823/4981)
# Obtaining fair value for SPI (4824/4981)
# Obtaining fair value for MARK (4825/4981)
# Obtaining fair value for NAVKARCORP.NS (4826/4981)
# Failed to obtain fair value for NAVKARCORP.NS
# list index out of range
# Obtaining fair value for WRAP (4827/4981)
# Obtaining fair value for HALL (4828/4981)
# Obtaining fair value for BOXL (4829/4981)
# Obtaining fair value for TRVN (4830/4981)
# Obtaining fair value for CRVS (4831/4981)
# Obtaining fair value for PRQR (4832/4981)
# Obtaining fair value for GEN (4833/4981)
# Obtaining fair value for DERM (4834/4981)
# Obtaining fair value for ITRM (4835/4981)
# Obtaining fair value for GECC (4836/4981)
# Obtaining fair value for SYRS (4837/4981)
# Obtaining fair value for LOAN (4838/4981)
# Obtaining fair value for TPHS (4839/4981)
# Obtaining fair value for HUSA (4840/4981)
# Obtaining fair value for LRFC (4841/4981)
# Obtaining fair value for BYSI (4842/4981)
# Obtaining fair value for CCEL (4843/4981)
# Obtaining fair value for SIDU (4844/4981)
# Obtaining fair value for RAIL (4845/4981)
# Obtaining fair value for BNOX (4846/4981)
# Obtaining fair value for GIFI (4847/4981)
# Obtaining fair value for TTOO (4848/4981)
# Obtaining fair value for RICOAUTO.NS (4849/4981)
# Failed to obtain fair value for RICOAUTO.NS
# list index out of range
# Obtaining fair value for XFOR (4850/4981)
# Obtaining fair value for FRSX (4851/4981)
# Obtaining fair value for RBL.NS (4852/4981)
# Failed to obtain fair value for RBL.NS
# list index out of range
# Obtaining fair value for BLGO (4853/4981)
# Obtaining fair value for MULN (4854/4981)
# Obtaining fair value for EVFM (4855/4981)
# Obtaining fair value for HMVL.NS (4856/4981)
# Failed to obtain fair value for HMVL.NS
# list index out of range
# Obtaining fair value for CI7.F (4857/4981)
# Failed to obtain fair value for CI7.F
# list index out of range
# Obtaining fair value for AVRO (4858/4981)
# Obtaining fair value for ACHV (4859/4981)
# Obtaining fair value for IZEA (4860/4981)
# Obtaining fair value for LPTH (4861/4981)
# Obtaining fair value for QUIK (4862/4981)
# Obtaining fair value for WWR (4863/4981)
# Obtaining fair value for ZEELEARN.NS (4864/4981)
# Failed to obtain fair value for ZEELEARN.NS
# list index out of range
# Obtaining fair value for GVKPIL.NS (4865/4981)
# Failed to obtain fair value for GVKPIL.NS
# list index out of range
# Obtaining fair value for SOPA (4866/4981)
# Obtaining fair value for DGLY (4867/4981)
# Obtaining fair value for PPSI (4868/4981)
# Obtaining fair value for CRBP (4869/4981)
# Obtaining fair value for SEAC (4870/4981)
# Obtaining fair value for KINS (4871/4981)
# Obtaining fair value for INUV (4872/4981)
# Obtaining fair value for GLYC (4873/4981)
# Obtaining fair value for NCTY (4874/4981)
# Obtaining fair value for SGMA (4875/4981)
# Obtaining fair value for YCBD (4876/4981)
# Obtaining fair value for BBGI (4877/4981)
# Obtaining fair value for BIOL (4878/4981)
# Obtaining fair value for MEP.NS (4879/4981)
# Failed to obtain fair value for MEP.NS
# list index out of range
# Obtaining fair value for XPL (4880/4981)
# Obtaining fair value for POLA (4881/4981)
# Obtaining fair value for COCP (4882/4981)
# Obtaining fair value for MRIN (4883/4981)
# Obtaining fair value for BMRA (4884/4981)
# Obtaining fair value for APM (4885/4981)
# Obtaining fair value for RFL (4886/4981)
# Obtaining fair value for UBX (4887/4981)
# Obtaining fair value for IGC (4888/4981)
# Obtaining fair value for TISI (4889/4981)
# Obtaining fair value for ACST (4890/4981)
# Obtaining fair value for GNLN (4891/4981)
# Obtaining fair value for TOPS (4892/4981)
# Obtaining fair value for ABEO (4893/4981)
# Obtaining fair value for VISL (4894/4981)
# Obtaining fair value for NCNA (4895/4981)
# Obtaining fair value for PLX (4896/4981)
# Obtaining fair value for AEZS (4897/4981)
# Obtaining fair value for OPGN (4898/4981)
# Obtaining fair value for OGEN (4899/4981)
# Obtaining fair value for NUZE (4900/4981)
# Obtaining fair value for AACG (4901/4981)
# Obtaining fair value for BSGM (4902/4981)
# Obtaining fair value for RGF (4903/4981)
# Obtaining fair value for RGLS (4904/4981)
# Obtaining fair value for BWEN (4905/4981)
# Obtaining fair value for VINE (4906/4981)
# Obtaining fair value for AYTU (4907/4981)
# Obtaining fair value for ECOR (4908/4981)
# Obtaining fair value for PMD (4909/4981)
# Obtaining fair value for CALA (4910/4981)
# Obtaining fair value for AIM (4911/4981)
# Obtaining fair value for VTVT (4912/4981)
# Obtaining fair value for FSC.NS (4913/4981)
# Failed to obtain fair value for FSC.NS
# list index out of range
# Obtaining fair value for MRAI (4914/4981)
# Obtaining fair value for VVPR (4915/4981)
# Obtaining fair value for 3667.T (4916/4981)
# Failed to obtain fair value for 3667.T
# list index out of range
# Obtaining fair value for OTRK (4917/4981)
# Obtaining fair value for MBOT (4918/4981)
# Obtaining fair value for RKDA (4919/4981)
# Obtaining fair value for ASTC (4920/4981)
# Obtaining fair value for EKSO (4921/4981)
# Obtaining fair value for ALRN (4922/4981)
# Obtaining fair value for ISPC (4923/4981)
# Obtaining fair value for GLMD (4924/4981)
# Obtaining fair value for RMTI (4925/4981)
# Obtaining fair value for ZKIN (4926/4981)
# Obtaining fair value for 4174.T (4927/4981)
# Failed to obtain fair value for 4174.T
# list index out of range
# Obtaining fair value for VYNE (4928/4981)
# Obtaining fair value for SNGX (4929/4981)
# Obtaining fair value for PRPO (4930/4981)
# Obtaining fair value for AGRX (4931/4981)
# Obtaining fair value for DLPN (4932/4981)
# Obtaining fair value for FGI (4933/4981)
# Obtaining fair value for GENE (4934/4981)
# Obtaining fair value for YTEN (4935/4981)
# Obtaining fair value for SNAX (4936/4981)
# Obtaining fair value for AIRI (4937/4981)
# Obtaining fair value for CANF (4938/4981)
# Obtaining fair value for FCP.LS (4939/4981)
# Failed to obtain fair value for FCP.LS
# list index out of range
# Obtaining fair value for AHI (4940/4981)
# Obtaining fair value for BLBX (4941/4981)
# Obtaining fair value for CARV (4942/4981)
# Obtaining fair value for PT (4943/4981)
# Obtaining fair value for PTPI (4944/4981)
# Obtaining fair value for PULM (4945/4981)
# Obtaining fair value for APCX (4946/4981)
# Obtaining fair value for SGBX (4947/4981)
# Obtaining fair value for NNVC (4948/4981)
# Obtaining fair value for 4199.T (4949/4981)
# Failed to obtain fair value for 4199.T
# list index out of range
# Obtaining fair value for TRIB (4950/4981)
# Obtaining fair value for WHLR (4951/4981)
# Obtaining fair value for RAVE (4952/4981)
# Obtaining fair value for AEMD (4953/4981)
# Obtaining fair value for OLB (4954/4981)
# Obtaining fair value for BLPH (4955/4981)
# Obtaining fair value for BKYI (4956/4981)
# Obtaining fair value for ADXS (4957/4981)
# Obtaining fair value for AVGR (4958/4981)
# Obtaining fair value for BNTC (4959/4981)
# Obtaining fair value for EVOK (4960/4981)
# Obtaining fair value for TPST (4961/4981)
# Obtaining fair value for EAST (4962/4981)
# Obtaining fair value for PSHG (4963/4981)
# Obtaining fair value for TIVC (4964/4981)
# Obtaining fair value for CING (4965/4981)
# Obtaining fair value for BHAT (4966/4981)
# Obtaining fair value for CETX (4967/4981)
# Obtaining fair value for CYTO (4968/4981)
# Obtaining fair value for GROM (4969/4981)
# Obtaining fair value for HSDT (4970/4981)
# Obtaining fair value for PIK (4971/4981)
# Obtaining fair value for STAF (4972/4981)
# Obtaining fair value for SINT (4973/4981)
# Obtaining fair value for TTNP (4974/4981)
# Obtaining fair value for PRFX (4975/4981)
# Obtaining fair value for SONM (4976/4981)
# Obtaining fair value for VIVE (4977/4981)
# Obtaining fair value for DRCT (4978/4981)
# Obtaining fair value for EFOI (4979/4981)
# Obtaining fair value for JAN (4980/4981)
# Obtaining fair value for INTS (4981/4981)
